# %%
# Reading in the data:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.interpolate import interp1d
import matplotlib 
import sklearn 
import xgboost as xgb
from xgboost.sklearn import XGBClassifier
from sklearn import cross_validation, metrics   #Additional scklearn functions
from sklearn.grid_search import GridSearchCV   #Performing grid search
import ipywidgets as widgets
from ipywidgets import FloatSlider, fixed
from ipywidgets.widgets.widget_selection import SelectionSlider
# Out:
# /mnt/raid-cita/nhussain/venv-2.7.13/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /mnt/raid-cita/nhussain/venv-2.7.13/lib/python2.7/site-packages/sklearn/grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
df = pd.read_csv('../csvs/initial_orbital_elements.csv', index_col=0)
del df['instability_time']
del df['Rel_Eerr']
Nrows = df.shape[0]
df.head()
print Nrows, len(np.where(df['Stable']==0)[0])
# Out:
# 14999 9075

# %%
df_X= df.ix[:,2:]
df_Y=df['Stable']
df_X.head()
# Out:
#     RHill12   RHill23     beta12     beta23            m1   a1        P1  \
# 0  0.026033  0.023222   8.508586  15.826967  3.414016e-05  1.0  0.999983
# 1  0.022704  0.031284   8.397002  15.367618  2.529838e-07  1.0  1.000000
# 2  0.036304  0.032149   3.461288  25.229467  7.380789e-05  1.0  0.999963
# 3  0.011704  0.014963  18.513681  19.145889  5.174804e-07  1.0  1.000000
# 4  0.006199  0.008634   5.494196   2.928938  5.106746e-07  1.0  1.000000
#
#          e1   pomega1      inc1    ...       Omega2        f2            m3  \
# 0  0.005031  3.171041  0.008978    ...     1.573978 -0.567081  1.826900e-06
# 1  0.010350 -3.564030  0.001541    ...    -1.749616  1.437355  1.955797e-05
# 2  0.051912  0.995149  0.016289    ...    -0.032550 -0.317958  1.477931e-07
# 3  0.000152 -3.328433  0.003301    ...     0.946351 -2.294238  1.287851e-06
# 4  0.001457  1.738448  0.033910    ...    -0.455684 -1.074927  1.542321e-06
#
#          a3        P3        e3   pomega3      inc3    Omega3        f3
# 0  1.589043  2.003050  0.002515 -0.108162  0.065498 -1.192440 -0.614709
# 1  1.671403  2.160777  0.072450 -0.343874  0.046939 -0.619350  0.192203
# 2  1.936762  2.695151  0.003395  3.419165  0.014535  2.795101  1.685406
# 3  1.503164  1.842927  0.057380 -0.829096  0.098014 -2.995941 -1.625763
# 4  1.059346  1.090326  0.010325 -1.214839  0.011840 -1.253823  1.215392
#
# [5 rows x 28 columns]

# %%
model = XGBClassifier(seed=27, learning_rate=0.1, n_estimators=100) # taken from fitting ROC_AUC

# %%
Nfolds = 5
max_depth = [6,12,18]
min_child_weight = np.logspace(-1,2,3)
param_grid = dict(max_depth=max_depth, min_child_weight=min_child_weight)

# %%
grid = GridSearchCV(estimator = model, param_grid = param_grid, scoring='average_precision',iid=False, cv=Nfolds, verbose = 15, n_jobs = -1 )
grid.fit(df.ix[:, 2:],df['Stable'])
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] max_depth=6, min_child_weight=0.1 ...............................
# [CV] max_depth=6, min_child_weight=0.1 ...............................
# [CV] ...... max_depth=6, min_child_weight=0.1, score=0.954151 -  26.4s
# [CV] max_depth=6, min_child_weight=0.1 ...............................
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:   26.5s
# [CV] ...... max_depth=6, min_child_weight=0.1, score=0.959085 -  27.3s
# [CV] max_depth=6, min_child_weight=0.1 ...............................
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:   27.4s
# [CV] ...... max_depth=6, min_child_weight=0.1, score=0.957190 -  23.6s
# [CV] max_depth=6, min_child_weight=0.1 ...............................
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:   50.1s
# [CV] ...... max_depth=6, min_child_weight=0.1, score=0.959837 -  22.9s
# [CV] max_depth=6, min_child_weight=3.16227766017 .....................
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:   50.3s
# [CV]  max_depth=6, min_child_weight=3.16227766017, score=0.954599 -  23.1s
# [CV] max_depth=6, min_child_weight=3.16227766017 .....................
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:  1.2min
# [CV] ...... max_depth=6, min_child_weight=0.1, score=0.959276 -  24.9s
# [CV] max_depth=6, min_child_weight=3.16227766017 .....................
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:  1.3min
# [CV]  max_depth=6, min_child_weight=3.16227766017, score=0.959653 -  27.7s
# [CV] max_depth=6, min_child_weight=3.16227766017 .....................
# [CV]  max_depth=6, min_child_weight=3.16227766017, score=0.957696 -  26.3s
# [CV] max_depth=6, min_child_weight=3.16227766017 .....................
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:  1.7min
# [CV]  max_depth=6, min_child_weight=3.16227766017, score=0.959819 -  27.4s
# [CV] max_depth=6, min_child_weight=100.0 .............................
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:  2.1min
# [CV]  max_depth=6, min_child_weight=3.16227766017, score=0.959590 -  28.7s
# [CV] max_depth=6, min_child_weight=100.0 .............................
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:  2.2min
# [CV] .... max_depth=6, min_child_weight=100.0, score=0.947538 -  19.8s
# [CV] max_depth=6, min_child_weight=100.0 .............................
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:  2.5min
# [CV] .... max_depth=6, min_child_weight=100.0, score=0.952649 -  19.2s
# [CV] max_depth=6, min_child_weight=100.0 .............................
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:  2.5min
# [CV] .... max_depth=6, min_child_weight=100.0, score=0.951090 -  17.6s
# [CV] max_depth=6, min_child_weight=100.0 .............................
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:  2.8min
# [CV] .... max_depth=6, min_child_weight=100.0, score=0.953756 -  20.1s
# [CV] max_depth=12, min_child_weight=0.1 ..............................
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:  2.8min
# [CV] .... max_depth=6, min_child_weight=100.0, score=0.949915 -  14.4s
# [CV] max_depth=12, min_child_weight=0.1 ..............................
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:  3.0min
# [CV] ..... max_depth=12, min_child_weight=0.1, score=0.951294 - 1.4min
# [CV] max_depth=12, min_child_weight=0.1 ..............................
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:  4.2min
# [CV] ..... max_depth=12, min_child_weight=0.1, score=0.957413 - 1.3min
# [CV] max_depth=12, min_child_weight=0.1 ..............................
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  4.3min
# [CV] ..... max_depth=12, min_child_weight=0.1, score=0.951462 -  58.5s
# [CV] max_depth=12, min_child_weight=0.1 ..............................
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:  5.2min
# [CV] ..... max_depth=12, min_child_weight=0.1, score=0.958079 -  57.7s
# [CV] max_depth=12, min_child_weight=3.16227766017 ....................
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:  5.3min
# [CV]  max_depth=12, min_child_weight=3.16227766017, score=0.954333 -  48.8s
# [CV] max_depth=12, min_child_weight=3.16227766017 ....................
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:  6.1min
# [CV] ..... max_depth=12, min_child_weight=0.1, score=0.958164 - 1.1min
# [CV] max_depth=12, min_child_weight=3.16227766017 ....................
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:  6.3min
# [CV]  max_depth=12, min_child_weight=3.16227766017, score=0.960074 -  54.0s
# [CV] max_depth=12, min_child_weight=3.16227766017 ....................
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:  7.0min
# [CV]  max_depth=12, min_child_weight=3.16227766017, score=0.957514 -  51.6s
# [CV] max_depth=12, min_child_weight=3.16227766017 ....................
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:  7.2min
# [CV]  max_depth=12, min_child_weight=3.16227766017, score=0.960225 -  41.0s
# [CV] max_depth=12, min_child_weight=100.0 ............................
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  7.7min
# [CV]  max_depth=12, min_child_weight=3.16227766017, score=0.958435 -  39.6s
# [CV] max_depth=12, min_child_weight=100.0 ............................
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  7.8min
# [CV] ... max_depth=12, min_child_weight=100.0, score=0.947570 -  16.9s
# [CV] max_depth=12, min_child_weight=100.0 ............................
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:  8.0min
# [CV] ... max_depth=12, min_child_weight=100.0, score=0.952228 -  18.3s
# [CV] max_depth=12, min_child_weight=100.0 ............................
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:  8.2min
# [CV] ... max_depth=12, min_child_weight=100.0, score=0.950927 -  15.0s
# [CV] max_depth=12, min_child_weight=100.0 ............................
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:  8.2min
# [CV] ... max_depth=12, min_child_weight=100.0, score=0.953395 -  16.3s
# [CV] max_depth=18, min_child_weight=0.1 ..............................
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:  8.4min
# [CV] ... max_depth=12, min_child_weight=100.0, score=0.949396 -  20.8s
# [CV] max_depth=18, min_child_weight=0.1 ..............................
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:  8.6min
# [CV] ..... max_depth=18, min_child_weight=0.1, score=0.950480 - 1.6min
# [CV] max_depth=18, min_child_weight=0.1 ..............................
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed: 10.0min
# [CV] ..... max_depth=18, min_child_weight=0.1, score=0.957926 - 1.5min
# [CV] max_depth=18, min_child_weight=0.1 ..............................
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed: 10.1min
# [CV] ..... max_depth=18, min_child_weight=0.1, score=0.951211 -  58.8s
# [CV] max_depth=18, min_child_weight=0.1 ..............................
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed: 11.0min
# [CV] ..... max_depth=18, min_child_weight=0.1, score=0.956732 - 1.1min
# [CV] max_depth=18, min_child_weight=3.16227766017 ....................
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed: 11.2min
# [CV]  max_depth=18, min_child_weight=3.16227766017, score=0.954204 -  52.0s
# [CV] max_depth=18, min_child_weight=3.16227766017 ....................
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed: 12.0min
# [CV] ..... max_depth=18, min_child_weight=0.1, score=0.956532 - 1.4min
# [CV] max_depth=18, min_child_weight=3.16227766017 ....................
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed: 12.4min
# [CV]  max_depth=18, min_child_weight=3.16227766017, score=0.961120 -  43.2s
# [CV] max_depth=18, min_child_weight=3.16227766017 ....................
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed: 12.8min
# [CV]  max_depth=18, min_child_weight=3.16227766017, score=0.955793 -  32.8s
# [CV] max_depth=18, min_child_weight=3.16227766017 ....................
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed: 12.9min
# [CV]  max_depth=18, min_child_weight=3.16227766017, score=0.960376 -  36.6s
# [CV] max_depth=18, min_child_weight=100.0 ............................
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed: 13.4min
# [CV] ... max_depth=18, min_child_weight=100.0, score=0.947570 -  17.5s
# [CV] max_depth=18, min_child_weight=100.0 ............................
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed: 13.7min
# [CV]  max_depth=18, min_child_weight=3.16227766017, score=0.958638 -  46.8s
# [CV] max_depth=18, min_child_weight=100.0 ............................
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed: 13.7min
# [CV] ... max_depth=18, min_child_weight=100.0, score=0.952228 -  16.1s
# [CV] max_depth=18, min_child_weight=100.0 ............................
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 13.9min
# [CV] ... max_depth=18, min_child_weight=100.0, score=0.950927 -  17.8s
# [CV] max_depth=18, min_child_weight=100.0 ............................
# [CV] ... max_depth=18, min_child_weight=100.0, score=0.953395 -  14.7s
# [CV] ... max_depth=18, min_child_weight=100.0, score=0.949396 -  10.5s
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed: 14.2min finished
# GridSearchCV(cv=5, error_score='raise',
#        estimator=XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=1,
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=3,
#        min_child_weight=1, missing=None, n_estimators=100, nthread=-1,
#        objective='binary:logistic', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=27, silent=True, subsample=1),
#        fit_params={}, iid=False, n_jobs=-1,
#        param_grid={'max_depth': [6, 12, 18], 'min_child_weight': array([   0.1    ,    3.16228,  100.     ])},
#        pre_dispatch='2*n_jobs', refit=True, scoring='average_precision',
#        verbose=15)

# %%
# get the names of the parameters
param_names = param_grid.keys()
param_vals = [[val for val in param_grid[param_name]] for param_name in param_names]
param_val_names = {param_name:["{0}".format(val) for val in param_grid[param_name]] for param_name in param_names}

# %%
# %matplotlib inline
from matplotlib.colors import Normalize
class MidpointNormalize(Normalize):

    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        x, y = [self.vmin, self.midpoint, self.vmax], [0, 0.5, 1]
        return np.ma.masked_array(np.interp(value, x, y))

def plotgrid(grid, vmin, vmax, midpoint):
    param_grid = grid.param_grid
    
    # get the names of the parameters
    param1 = param_grid.keys()[0]
    param2 = param_grid.keys()[1]

    # plot the scores of the grid
    # grid_scores_ contains parameter settings and scores
    # We extract just the scores
    scores = np.fabs([x[1] for x in grid.grid_scores_])
    scores = np.array(scores).reshape(len(param_grid[param1]), len(param_grid[param2]))

    plt.figure(figsize=(12, 6))
    plt.subplots_adjust(left=.2, right=0.95, bottom=0.15, top=0.95)
    plt.imshow(scores, interpolation='nearest', cmap=plt.cm.hot, norm=MidpointNormalize(vmin=vmin, vmax=vmax, midpoint=midpoint))
    plt.xlabel(param2)
    plt.ylabel(param1)
    plt.colorbar()
    plt.xticks(np.arange(len(param_grid[param2])), np.round(param_grid[param2], decimals=2))
    plt.yticks(np.arange(len(param_grid[param1])), np.round(param_grid[param1], decimals=2))
    plt.title('CV Score')
    plt.show()
       
def plot1dcut(grid, param_names, fixed_param_name, fixed_value_name):
    fixed_value = float(fixed_value_name)
    param_grid = grid.param_grid
    
    # Each entry x in grid.grid_scores_ has all the CV scores in x[2]
    scores = np.fabs([np.mean(x[2]) for x in grid.grid_scores_])
    stds = np.fabs([np.std(x[2]) for x in grid.grid_scores_])
    scores = np.array(scores).reshape(len(param_grid[param_names[0]]), len(param_grid[param_names[1]]))
    stds = np.array(stds).reshape(len(param_grid[param_names[0]]), len(param_grid[param_names[1]]))
    
    plt.figure(figsize=(8, 6))
    fig, ax = plt.subplots()
    
    if fixed_param_name == param_names[0]:
        xvals = param_grid[param_names[1]] # take all the values in param grid for the other parameter
        mask = np.isclose(np.array(grid.param_grid[fixed_param_name]), fixed_value) # make masked array of passed parameter to pick out right index
        yvals = scores[mask,:].flatten()
        errs = stds[mask,:].flatten()/np.sqrt(Nfolds)
        ax.set_xlabel(param_names[1])

    elif fixed_param_name == param_names[1]:
        xvals = param_grid[param_names[0]] # take all the values in param grid for the other parameter
        mask = np.isclose(np.array(grid.param_grid[fixed_param_name]), fixed_value) # make masked array of passed parameter to pick out right index
        yvals = scores[:,mask].flatten()
        errs = stds[:,mask].flatten()/np.sqrt(Nfolds)
        ax.set_xlabel(param_names[0])

    ax.errorbar(xvals, yvals, errs)
    ax.set_ylabel('CV score')
    ax.set_title("{0} = {1}".format(fixed_param_name, fixed_value))
    plt.show()

# %%
def plot_grid_Scores(grid):
    #plot map of performance across the parameter space

    # get the scores and values for the sliders
    scores = np.fabs([x[1] for x in grid.grid_scores_])
    vmin = np.min(scores)
    vmax = np.max(scores)
    mean = np.mean(scores)
    step = (vmax-vmin)/100.

    widgets.interact(plotgrid, grid=fixed(grid), vmin=FloatSlider(min=vmin, max=vmax, step=step, value=vmin), 
                 vmax=FloatSlider(min=vmin, max=vmax, step=step, value=vmax), 
                 midpoint=FloatSlider(min=vmin, max=vmax, step=step, value=mean))

# %%
plot_grid_Scores(grid)
# Out:
# <function __main__.plotgrid>

# %% [markdown]
# From the above grid, it seems that having a min child weight of about with order of magnitude ~1 regardless of max depth is a good parameter space to get a good score, but only marginally so.

# %% [markdown]
# Try manual hand tunning, since even running a small grid took 15 min, a tigher grid will tkae that much longer
# General Guidelines:
#
# 1)adjust depth (integer), starts at 6, then 8, 10....(6-12-18 is common) Stop increasing when CV performance drops.
#
# 2)adjust col_sample_by tree and subsample. Standard values are between 0.5-1
#
# 3)adjust min_child_weight (note: this is a float). try values from 0.1 to 10, some data benefit with 150-200.
#
# 4)adjust eta and n_round (estimators in concert). eta=0.1 is a good start, but optimal is typically 0.05 to 1e-3. n_round optimal is typically from 1000 to 12000 in my experience.

# %%
min_child_w = 3
n_est=100
max_d = 8
learning_r = 0.1
model2 = XGBClassifier(min_child_weight=min_child_w, n_estimators=n_est, max_depth=max_d, learning_rate=learning_r)
from sklearn.model_selection import cross_val_score

# %%
score = cross_val_score(estimator=model2, n_jobs=-1, cv = 5, X = df_X, y = df_Y, scoring ='average_precision', verbose = 5)
# Out:
# [CV]  ................................................................
# [CV]  ................................................................
# [CV] ................................. , score=0.959790, total=  36.1s
# [CV]  ................................................................
# [CV] ................................. , score=0.956826, total=  36.5s
# [CV]  ................................................................
# [CV] ................................. , score=0.956826, total=  30.3s
# [CV]  ................................................................
# [CV] ................................. , score=0.961051, total=  30.6s
# [CV] ................................. , score=0.958689, total=   6.8s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.2min finished

# %%
def scoring (model, scoring = 'f1'):
    score = cross_val_score(estimator=model2, n_jobs=-1, cv = 5, X = df_X, y = df_Y, scoring =scoring, verbose = 5)
    print('This is the std of the model scores: %f', np.std(score))
    print('This is the average score from CV: %f', np.mean(score))

# %%
scoring (model2)
# Out:
# [CV]  ................................................................
# [CV]  ................................................................
# [CV] ................................. , score=0.883249, total=  24.9s
# [CV]  ................................................................
# [CV] ................................. , score=0.890499, total=  25.8s
# [CV]  ................................................................
# [CV] ................................. , score=0.884746, total=  28.8s
# [CV]  ................................................................
# [CV] ................................. , score=0.879863, total=  28.0s
# [CV] ................................. , score=0.889080, total=   6.5s
# ('This is the std of the model scores: %f', 0.0038784313340582471)
# ('This is the average score from CV: %f', 0.88548723148285102)
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.0min finished

# %%
from sklearn.metrics import classification_report
Nrows = df.shape[0]
Nrows_train = int(Nrows*0.1) # use 10% total

trainData = df_X.iloc[:Nrows_train/2]
testData = df_X.iloc[Nrows_train/2:Nrows_train]
#print trainData.shape
trainY = df_Y[:Nrows_train/2]
#testData = df_X.iloc[Nrows_train:]
testY = df_Y[Nrows_train/2:Nrows_train]
model2.fit(trainData, trainY)
predY = model2.predict(testData)
print metrics.accuracy_score(testY, predY), metrics.f1_score(testY, predY)
#scoring(model2)
cm = metrics.confusion_matrix(testY, predY, labels=[1, 0]) #stable, unstable
# Out:
# 0.868 0.831918505942

# %%
#dtrain_predprob = model2.fit
model2.fit(trainData, trainY)
dtest_predprob = model2.predict_proba(testData)[:,1]
#print dtest_predprob[:][:5]

# %%
#Print model report:
print "\nModel Report"
print "Accuracy : %.4g" % metrics.accuracy_score(testY, predY)
#print "AUC Score (Train): %f" % metrics.roc_auc_score(df['Stable'], dtrain_predprob)
print "AUC Score (Test): %f" % metrics.average_precision_score(testY, dtest_predprob)

xgb.plot_importance(model2, height = 0.4 )
# Out:
# Model Report
# Accuracy : 0.868
# AUC Score (Test): 0.930540

# %%
import matplotlib
# %matplotlib inline
def plot_confusion_matrix(cm, title='Confusion Matrix', cmap=plt.cm.Greens):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(2)
    plt.xticks(tick_marks, ['Stable', 'Unstable'], rotation=45)
    plt.yticks(tick_marks, ['Stable', 'Unstable'])
    plt.tight_layout()
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.clf()
    plt.show()
plot_confusion_matrix(cm)

# %%
fig, ax= plt.subplots(figsize=(8, 5))
ax.hist(dtest_predprob, bins=50, alpha=0.5, color='green', linewidth = 1, edgecolor='black',)
ax.set_xlabel('Predicted Prob', fontsize=14)
ax.set_ylabel('Counts - All', fontsize=14)
plt.show()

# %% [markdown]
# Compare prediction results to weather they were stable or unstable

# %%
# Histogram:

bins = 50
pred_prob= model2.predict_proba(testData)[:,1]
Stable=pred_prob[np.where(testY==1)]
print Stable[:5][:]
Unstable=pred_prob[np.where(testY==0)]
print Stable.size, Unstable.size

fig, ax1 = plt.subplots()
ax1.hist([Unstable, Stable], bins, alpha=0.5, label='No', color=['blue', 'green'], linewidth = 1, edgecolor='black', histtype='barstacked')
ax1.set_xlabel('Predicted Probability', fontsize=14)
ax1.set_ylabel('Unstable',  fontsize=14, color='blue')
for tl in ax1.get_yticklabels():
    tl.set_color('blue')
    

ax2 = ax1.twinx()
#ax2.hist(Stable, bins, alpha=0.5, label='Yes',color='green', linewidth = 1, edgecolor='black', histtype='barstacked')
ax2.set_ylabel('Stable', fontsize=14, color='green')
for tl in ax2.get_yticklabels():
    tl.set_color('green')
 
#ax1.set_ylim(ax2.get_ylim())
ax1.set_ylim([0,250])
ax2.set_ylim([0,40])
# Out:
# [ 0.95075196  0.16707779  0.41528997  0.16427894  0.9468655 ]
# 304 446
# (0, 40)

# %% [markdown]
# Make a tighter grid

# %%
model3 = XGBClassifier(seed = 3, n_estimators=100, learning_rate=0.1, max_depth=4, min_child_weight=np.log10(1.5))
model3.fit(df_X.iloc[:Nrows_train/2], df_Y[:Nrows_train/2])
pred = model3.predict(df_X.iloc[Nrows_train/2:Nrows_train])
print np.logspace(np.log10(1.5),np.log10(10), 6)
print df_X.iloc[:Nrows_train].shape
# Out:
# [  1.5          2.19216383   3.2037215    4.68205492   6.84255429  10.        ]
# (1499, 28)

# %%
model3 = XGBClassifier(seed = 3, n_estimators=100, learning_rate=0.1)

max_depth = [4,6,8,10, 12, 14]
min_child_weight = np.logspace(np.log10(1.5),np.log10(10), 6)
#n_estim = [200]

param_grid = dict(max_depth=max_depth, min_child_weight=min_child_weight)
grid = GridSearchCV(estimator = model3, param_grid = param_grid, scoring='average_precision',iid=False,cv=5, verbose = 15)
grid.fit(df_X.iloc[:Nrows_train], df_Y[:Nrows_train]) #10% of total dataset

# get the names of the parameters
param_names = param_grid.keys()
param_vals = [[val for val in param_grid[param_name]] for param_name in param_names]
param_val_names = {param_name:["{0}".format(val) for val in param_grid[param_name]] for param_name in param_names}
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] max_depth=4, min_child_weight=1.5 ...............................
# [CV] ...... max_depth=4, min_child_weight=1.5, score=0.893787 -   1.5s
# [CV] max_depth=4, min_child_weight=1.5 ...............................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s remaining:    0.0s
# [CV] ...... max_depth=4, min_child_weight=1.5, score=0.914440 -   9.1s
# [CV] max_depth=4, min_child_weight=1.5 ...............................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   10.7s remaining:    0.0s
# [CV] ...... max_depth=4, min_child_weight=1.5, score=0.942746 -   4.3s
# [CV] max_depth=4, min_child_weight=1.5 ...............................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   15.0s remaining:    0.0s
# [CV] ...... max_depth=4, min_child_weight=1.5, score=0.946287 -   1.3s
# [CV] max_depth=4, min_child_weight=1.5 ...............................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   16.3s remaining:    0.0s
# [CV] ...... max_depth=4, min_child_weight=1.5, score=0.954174 -   1.0s
# [CV] max_depth=4, min_child_weight=2.19216382743 .....................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   17.3s remaining:    0.0s
# [CV]  max_depth=4, min_child_weight=2.19216382743, score=0.887869 -   3.8s
# [CV] max_depth=4, min_child_weight=2.19216382743 .....................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   21.1s remaining:    0.0s
# [CV]  max_depth=4, min_child_weight=2.19216382743, score=0.918228 -   2.1s
# [CV] max_depth=4, min_child_weight=2.19216382743 .....................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   23.1s remaining:    0.0s
# [CV]  max_depth=4, min_child_weight=2.19216382743, score=0.945267 -   2.4s
# [CV] max_depth=4, min_child_weight=2.19216382743 .....................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   25.6s remaining:    0.0s
# [CV]  max_depth=4, min_child_weight=2.19216382743, score=0.949559 -   8.8s
# [CV] max_depth=4, min_child_weight=2.19216382743 .....................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   34.3s remaining:    0.0s
# [CV]  max_depth=4, min_child_weight=2.19216382743, score=0.954618 -   8.8s
# [CV] max_depth=4, min_child_weight=3.20372149754 .....................
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:   43.1s remaining:    0.0s
# [CV]  max_depth=4, min_child_weight=3.20372149754, score=0.895718 -   8.7s
# [CV] max_depth=4, min_child_weight=3.20372149754 .....................
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:   51.8s remaining:    0.0s
# [CV]  max_depth=4, min_child_weight=3.20372149754, score=0.911565 -   4.3s
# [CV] max_depth=4, min_child_weight=3.20372149754 .....................
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:   56.1s remaining:    0.0s
# [CV]  max_depth=4, min_child_weight=3.20372149754, score=0.939810 -   8.3s
# [CV] max_depth=4, min_child_weight=3.20372149754 .....................
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:  1.1min remaining:    0.0s
# [CV]  max_depth=4, min_child_weight=3.20372149754, score=0.946535 -   7.9s
# [CV] max_depth=4, min_child_weight=3.20372149754 .....................
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:  1.2min remaining:    0.0s
# [CV]  max_depth=4, min_child_weight=3.20372149754, score=0.955781 -   9.2s
# [CV] max_depth=4, min_child_weight=4.68205492005 .....................
# [CV]  max_depth=4, min_child_weight=4.68205492005, score=0.893882 -   3.9s
# [CV] max_depth=4, min_child_weight=4.68205492005 .....................
# [CV]  max_depth=4, min_child_weight=4.68205492005, score=0.918794 -   5.8s
# [CV] max_depth=4, min_child_weight=4.68205492005 .....................
# [CV]  max_depth=4, min_child_weight=4.68205492005, score=0.942635 -   1.6s
# [CV] max_depth=4, min_child_weight=4.68205492005 .....................
# [CV]  max_depth=4, min_child_weight=4.68205492005, score=0.948996 -   5.6s
# [CV] max_depth=4, min_child_weight=4.68205492005 .....................
# [CV]  max_depth=4, min_child_weight=4.68205492005, score=0.956419 -   4.1s
# [CV] max_depth=4, min_child_weight=6.84255428919 .....................
# [CV]  max_depth=4, min_child_weight=6.84255428919, score=0.895590 -   7.9s
# [CV] max_depth=4, min_child_weight=6.84255428919 .....................
# [CV]  max_depth=4, min_child_weight=6.84255428919, score=0.917227 -   7.8s
# [CV] max_depth=4, min_child_weight=6.84255428919 .....................
# [CV]  max_depth=4, min_child_weight=6.84255428919, score=0.944847 -   7.8s
# [CV] max_depth=4, min_child_weight=6.84255428919 .....................
# [CV]  max_depth=4, min_child_weight=6.84255428919, score=0.946354 -   4.6s
# [CV] max_depth=4, min_child_weight=6.84255428919 .....................
# [CV]  max_depth=4, min_child_weight=6.84255428919, score=0.948329 -   0.7s
# [CV] max_depth=4, min_child_weight=10.0 ..............................
# [CV] ..... max_depth=4, min_child_weight=10.0, score=0.891916 -   0.6s
# [CV] max_depth=4, min_child_weight=10.0 ..............................
# [CV] ..... max_depth=4, min_child_weight=10.0, score=0.908822 -   0.7s
# [CV] max_depth=4, min_child_weight=10.0 ..............................
# [CV] ..... max_depth=4, min_child_weight=10.0, score=0.935024 -   0.6s
# [CV] max_depth=4, min_child_weight=10.0 ..............................
# [CV] ..... max_depth=4, min_child_weight=10.0, score=0.945561 -   0.6s
# [CV] max_depth=4, min_child_weight=10.0 ..............................
# [CV] ..... max_depth=4, min_child_weight=10.0, score=0.952853 -   1.7s
# [CV] max_depth=6, min_child_weight=1.5 ...............................
# [CV] ...... max_depth=6, min_child_weight=1.5, score=0.900456 -   0.8s
# [CV] max_depth=6, min_child_weight=1.5 ...............................
# [CV] ...... max_depth=6, min_child_weight=1.5, score=0.917106 -   3.1s
# [CV] max_depth=6, min_child_weight=1.5 ...............................
# [CV] ...... max_depth=6, min_child_weight=1.5, score=0.940890 -   1.5s
# [CV] max_depth=6, min_child_weight=1.5 ...............................
# [CV] ...... max_depth=6, min_child_weight=1.5, score=0.943920 -   0.5s
# [CV] max_depth=6, min_child_weight=1.5 ...............................
# [CV] ...... max_depth=6, min_child_weight=1.5, score=0.957669 -   1.7s
# [CV] max_depth=6, min_child_weight=2.19216382743 .....................
# [CV]  max_depth=6, min_child_weight=2.19216382743, score=0.896821 -   0.6s
# [CV] max_depth=6, min_child_weight=2.19216382743 .....................
# [CV]  max_depth=6, min_child_weight=2.19216382743, score=0.910001 -   0.6s
# [CV] max_depth=6, min_child_weight=2.19216382743 .....................
# [CV]  max_depth=6, min_child_weight=2.19216382743, score=0.941654 -   1.1s
# [CV] max_depth=6, min_child_weight=2.19216382743 .....................
# [CV]  max_depth=6, min_child_weight=2.19216382743, score=0.942845 -   1.3s
# [CV] max_depth=6, min_child_weight=2.19216382743 .....................
# [CV]  max_depth=6, min_child_weight=2.19216382743, score=0.952426 -   1.0s
# [CV] max_depth=6, min_child_weight=3.20372149754 .....................
# [CV]  max_depth=6, min_child_weight=3.20372149754, score=0.905328 -   0.7s
# [CV] max_depth=6, min_child_weight=3.20372149754 .....................
# [CV]  max_depth=6, min_child_weight=3.20372149754, score=0.914037 -   0.7s
# [CV] max_depth=6, min_child_weight=3.20372149754 .....................
# [CV]  max_depth=6, min_child_weight=3.20372149754, score=0.938676 -   0.9s
# [CV] max_depth=6, min_child_weight=3.20372149754 .....................
# [CV]  max_depth=6, min_child_weight=3.20372149754, score=0.945414 -   1.3s
# [CV] max_depth=6, min_child_weight=3.20372149754 .....................
# [CV]  max_depth=6, min_child_weight=3.20372149754, score=0.956925 -   0.8s
# [CV] max_depth=6, min_child_weight=4.68205492005 .....................
# [CV]  max_depth=6, min_child_weight=4.68205492005, score=0.900924 -   0.5s
# [CV] max_depth=6, min_child_weight=4.68205492005 .....................
# [CV]  max_depth=6, min_child_weight=4.68205492005, score=0.909427 -   0.8s
# [CV] max_depth=6, min_child_weight=4.68205492005 .....................
# [CV]  max_depth=6, min_child_weight=4.68205492005, score=0.942661 -   0.6s
# [CV] max_depth=6, min_child_weight=4.68205492005 .....................
# [CV]  max_depth=6, min_child_weight=4.68205492005, score=0.945966 -   0.6s
# [CV] max_depth=6, min_child_weight=4.68205492005 .....................
# [CV]  max_depth=6, min_child_weight=4.68205492005, score=0.957906 -   0.8s
# [CV] max_depth=6, min_child_weight=6.84255428919 .....................
# [CV]  max_depth=6, min_child_weight=6.84255428919, score=0.903345 -   0.5s
# [CV] max_depth=6, min_child_weight=6.84255428919 .....................
# [CV]  max_depth=6, min_child_weight=6.84255428919, score=0.920784 -   0.4s
# [CV] max_depth=6, min_child_weight=6.84255428919 .....................
# [CV]  max_depth=6, min_child_weight=6.84255428919, score=0.936948 -   0.5s
# [CV] max_depth=6, min_child_weight=6.84255428919 .....................
# [CV]  max_depth=6, min_child_weight=6.84255428919, score=0.945963 -   0.4s
# [CV] max_depth=6, min_child_weight=6.84255428919 .....................
# [CV]  max_depth=6, min_child_weight=6.84255428919, score=0.953021 -   0.4s
# [CV] max_depth=6, min_child_weight=10.0 ..............................
# [CV] ..... max_depth=6, min_child_weight=10.0, score=0.905862 -   0.3s
# [CV] max_depth=6, min_child_weight=10.0 ..............................
# [CV] ..... max_depth=6, min_child_weight=10.0, score=0.910594 -   0.3s
# [CV] max_depth=6, min_child_weight=10.0 ..............................
# [CV] ..... max_depth=6, min_child_weight=10.0, score=0.937669 -   1.1s
# [CV] max_depth=6, min_child_weight=10.0 ..............................
# [CV] ..... max_depth=6, min_child_weight=10.0, score=0.945609 -   0.3s
# [CV] max_depth=6, min_child_weight=10.0 ..............................
# [CV] ..... max_depth=6, min_child_weight=10.0, score=0.957663 -   0.4s
# [CV] max_depth=8, min_child_weight=1.5 ...............................
# [CV] ...... max_depth=8, min_child_weight=1.5, score=0.899733 -   0.7s
# [CV] max_depth=8, min_child_weight=1.5 ...............................
# [CV] ...... max_depth=8, min_child_weight=1.5, score=0.903500 -   0.9s
# [CV] max_depth=8, min_child_weight=1.5 ...............................
# [CV] ...... max_depth=8, min_child_weight=1.5, score=0.935854 -   0.9s
# [CV] max_depth=8, min_child_weight=1.5 ...............................
# [CV] ...... max_depth=8, min_child_weight=1.5, score=0.941041 -   0.6s
# [CV] max_depth=8, min_child_weight=1.5 ...............................
# [CV] ...... max_depth=8, min_child_weight=1.5, score=0.953803 -   0.7s
# [CV] max_depth=8, min_child_weight=2.19216382743 .....................
# [CV]  max_depth=8, min_child_weight=2.19216382743, score=0.905354 -   0.6s
# [CV] max_depth=8, min_child_weight=2.19216382743 .....................
# [CV]  max_depth=8, min_child_weight=2.19216382743, score=0.909581 -   1.2s
# [CV] max_depth=8, min_child_weight=2.19216382743 .....................
# [CV]  max_depth=8, min_child_weight=2.19216382743, score=0.934738 -   1.1s
# [CV] max_depth=8, min_child_weight=2.19216382743 .....................
# [CV]  max_depth=8, min_child_weight=2.19216382743, score=0.945057 -   1.9s
# [CV] max_depth=8, min_child_weight=2.19216382743 .....................
# [CV]  max_depth=8, min_child_weight=2.19216382743, score=0.952777 -   0.5s
# [CV] max_depth=8, min_child_weight=3.20372149754 .....................
# [CV]  max_depth=8, min_child_weight=3.20372149754, score=0.905312 -   0.8s
# [CV] max_depth=8, min_child_weight=3.20372149754 .....................
# [CV]  max_depth=8, min_child_weight=3.20372149754, score=0.916453 -   0.8s
# [CV] max_depth=8, min_child_weight=3.20372149754 .....................
# [CV]  max_depth=8, min_child_weight=3.20372149754, score=0.938215 -   1.2s
# [CV] max_depth=8, min_child_weight=3.20372149754 .....................
# [CV]  max_depth=8, min_child_weight=3.20372149754, score=0.945455 -   1.2s
# [CV] max_depth=8, min_child_weight=3.20372149754 .....................
# [CV]  max_depth=8, min_child_weight=3.20372149754, score=0.955836 -   2.2s
# [CV] max_depth=8, min_child_weight=4.68205492005 .....................
# [CV]  max_depth=8, min_child_weight=4.68205492005, score=0.901818 -   0.8s
# [CV] max_depth=8, min_child_weight=4.68205492005 .....................
# [CV]  max_depth=8, min_child_weight=4.68205492005, score=0.915405 -   1.0s
# [CV] max_depth=8, min_child_weight=4.68205492005 .....................
# [CV]  max_depth=8, min_child_weight=4.68205492005, score=0.940812 -   1.1s
# [CV] max_depth=8, min_child_weight=4.68205492005 .....................
# [CV]  max_depth=8, min_child_weight=4.68205492005, score=0.943063 -   0.9s
# [CV] max_depth=8, min_child_weight=4.68205492005 .....................
# [CV]  max_depth=8, min_child_weight=4.68205492005, score=0.956254 -   0.9s
# [CV] max_depth=8, min_child_weight=6.84255428919 .....................
# [CV]  max_depth=8, min_child_weight=6.84255428919, score=0.905014 -   0.5s
# [CV] max_depth=8, min_child_weight=6.84255428919 .....................
# [CV]  max_depth=8, min_child_weight=6.84255428919, score=0.904253 -   0.9s
# [CV] max_depth=8, min_child_weight=6.84255428919 .....................
# [CV]  max_depth=8, min_child_weight=6.84255428919, score=0.940104 -   0.8s
# [CV] max_depth=8, min_child_weight=6.84255428919 .....................
# [CV]  max_depth=8, min_child_weight=6.84255428919, score=0.943794 -   0.4s
# [CV] max_depth=8, min_child_weight=6.84255428919 .....................
# [CV]  max_depth=8, min_child_weight=6.84255428919, score=0.959648 -   0.4s
# [CV] max_depth=8, min_child_weight=10.0 ..............................
# [CV] ..... max_depth=8, min_child_weight=10.0, score=0.903487 -   0.4s
# [CV] max_depth=8, min_child_weight=10.0 ..............................
# [CV] ..... max_depth=8, min_child_weight=10.0, score=0.913265 -   0.4s
# [CV] max_depth=8, min_child_weight=10.0 ..............................
# [CV] ..... max_depth=8, min_child_weight=10.0, score=0.940349 -   0.4s
# [CV] max_depth=8, min_child_weight=10.0 ..............................
# [CV] ..... max_depth=8, min_child_weight=10.0, score=0.942383 -   0.4s
# [CV] max_depth=8, min_child_weight=10.0 ..............................
# [CV] ..... max_depth=8, min_child_weight=10.0, score=0.955175 -   0.8s
# [CV] max_depth=10, min_child_weight=1.5 ..............................
# [CV] ..... max_depth=10, min_child_weight=1.5, score=0.907769 -   1.3s
# [CV] max_depth=10, min_child_weight=1.5 ..............................
# [CV] ..... max_depth=10, min_child_weight=1.5, score=0.906068 -   0.9s
# [CV] max_depth=10, min_child_weight=1.5 ..............................
# [CV] ..... max_depth=10, min_child_weight=1.5, score=0.939792 -   0.7s
# [CV] max_depth=10, min_child_weight=1.5 ..............................
# [CV] ..... max_depth=10, min_child_weight=1.5, score=0.944692 -   0.6s
# [CV] max_depth=10, min_child_weight=1.5 ..............................
# [CV] ..... max_depth=10, min_child_weight=1.5, score=0.957959 -   0.6s
# [CV] max_depth=10, min_child_weight=2.19216382743 ....................
# [CV]  max_depth=10, min_child_weight=2.19216382743, score=0.903755 -   0.6s
# [CV] max_depth=10, min_child_weight=2.19216382743 ....................
# [CV]  max_depth=10, min_child_weight=2.19216382743, score=0.909601 -   0.6s
# [CV] max_depth=10, min_child_weight=2.19216382743 ....................
# [CV]  max_depth=10, min_child_weight=2.19216382743, score=0.936592 -   0.6s
# [CV] max_depth=10, min_child_weight=2.19216382743 ....................
# [CV]  max_depth=10, min_child_weight=2.19216382743, score=0.945167 -   0.6s
# [CV] max_depth=10, min_child_weight=2.19216382743 ....................
# [CV]  max_depth=10, min_child_weight=2.19216382743, score=0.954304 -   0.6s
# [CV] max_depth=10, min_child_weight=3.20372149754 ....................
# [CV]  max_depth=10, min_child_weight=3.20372149754, score=0.909711 -   0.7s
# [CV] max_depth=10, min_child_weight=3.20372149754 ....................
# [CV]  max_depth=10, min_child_weight=3.20372149754, score=0.919590 -   0.6s
# [CV] max_depth=10, min_child_weight=3.20372149754 ....................
# [CV]  max_depth=10, min_child_weight=3.20372149754, score=0.936904 -   0.5s
# [CV] max_depth=10, min_child_weight=3.20372149754 ....................
# [CV]  max_depth=10, min_child_weight=3.20372149754, score=0.941613 -   0.5s
# [CV] max_depth=10, min_child_weight=3.20372149754 ....................
# [CV]  max_depth=10, min_child_weight=3.20372149754, score=0.954449 -   0.6s
# [CV] max_depth=10, min_child_weight=4.68205492005 ....................
# [CV]  max_depth=10, min_child_weight=4.68205492005, score=0.901203 -   0.5s
# [CV] max_depth=10, min_child_weight=4.68205492005 ....................
# [CV]  max_depth=10, min_child_weight=4.68205492005, score=0.917940 -   0.5s
# [CV] max_depth=10, min_child_weight=4.68205492005 ....................
# [CV]  max_depth=10, min_child_weight=4.68205492005, score=0.936824 -   0.5s
# [CV] max_depth=10, min_child_weight=4.68205492005 ....................
# [CV]  max_depth=10, min_child_weight=4.68205492005, score=0.949353 -   0.5s
# [CV] max_depth=10, min_child_weight=4.68205492005 ....................
# [CV]  max_depth=10, min_child_weight=4.68205492005, score=0.957727 -   1.0s
# [CV] max_depth=10, min_child_weight=6.84255428919 ....................
# [CV]  max_depth=10, min_child_weight=6.84255428919, score=0.906360 -   0.5s
# [CV] max_depth=10, min_child_weight=6.84255428919 ....................
# [CV]  max_depth=10, min_child_weight=6.84255428919, score=0.916956 -   0.5s
# [CV] max_depth=10, min_child_weight=6.84255428919 ....................
# [CV]  max_depth=10, min_child_weight=6.84255428919, score=0.940063 -   0.6s
# [CV] max_depth=10, min_child_weight=6.84255428919 ....................
# [CV]  max_depth=10, min_child_weight=6.84255428919, score=0.947541 -   0.5s
# [CV] max_depth=10, min_child_weight=6.84255428919 ....................
# [CV]  max_depth=10, min_child_weight=6.84255428919, score=0.955511 -   0.5s
# [CV] max_depth=10, min_child_weight=10.0 .............................
# [CV] .... max_depth=10, min_child_weight=10.0, score=0.903559 -   0.6s
# [CV] max_depth=10, min_child_weight=10.0 .............................
# [CV] .... max_depth=10, min_child_weight=10.0, score=0.906776 -   0.4s
# [CV] max_depth=10, min_child_weight=10.0 .............................
# [CV] .... max_depth=10, min_child_weight=10.0, score=0.935899 -   0.4s
# [CV] max_depth=10, min_child_weight=10.0 .............................
# [CV] .... max_depth=10, min_child_weight=10.0, score=0.947258 -   0.4s
# [CV] max_depth=10, min_child_weight=10.0 .............................
# [CV] .... max_depth=10, min_child_weight=10.0, score=0.953942 -   0.4s
# [CV] max_depth=12, min_child_weight=1.5 ..............................
# [CV] ..... max_depth=12, min_child_weight=1.5, score=0.906609 -   0.6s
# [CV] max_depth=12, min_child_weight=1.5 ..............................
# [CV] ..... max_depth=12, min_child_weight=1.5, score=0.910584 -   0.6s
# [CV] max_depth=12, min_child_weight=1.5 ..............................
# [CV] ..... max_depth=12, min_child_weight=1.5, score=0.935204 -   0.6s
# [CV] max_depth=12, min_child_weight=1.5 ..............................
# [CV] ..... max_depth=12, min_child_weight=1.5, score=0.944166 -   0.6s
# [CV] max_depth=12, min_child_weight=1.5 ..............................
# [CV] ..... max_depth=12, min_child_weight=1.5, score=0.953640 -   0.6s
# [CV] max_depth=12, min_child_weight=2.19216382743 ....................
# [CV]  max_depth=12, min_child_weight=2.19216382743, score=0.902677 -   0.6s
# [CV] max_depth=12, min_child_weight=2.19216382743 ....................
# [CV]  max_depth=12, min_child_weight=2.19216382743, score=0.910268 -   0.5s
# [CV] max_depth=12, min_child_weight=2.19216382743 ....................
# [CV]  max_depth=12, min_child_weight=2.19216382743, score=0.938617 -   0.5s
# [CV] max_depth=12, min_child_weight=2.19216382743 ....................
# [CV]  max_depth=12, min_child_weight=2.19216382743, score=0.946269 -   0.5s
# [CV] max_depth=12, min_child_weight=2.19216382743 ....................
# [CV]  max_depth=12, min_child_weight=2.19216382743, score=0.950643 -   0.6s
# [CV] max_depth=12, min_child_weight=3.20372149754 ....................
# [CV]  max_depth=12, min_child_weight=3.20372149754, score=0.903283 -   0.8s
# [CV] max_depth=12, min_child_weight=3.20372149754 ....................
# [CV]  max_depth=12, min_child_weight=3.20372149754, score=0.913730 -   0.5s
# [CV] max_depth=12, min_child_weight=3.20372149754 ....................
# [CV]  max_depth=12, min_child_weight=3.20372149754, score=0.935062 -   0.6s
# [CV] max_depth=12, min_child_weight=3.20372149754 ....................
# [CV]  max_depth=12, min_child_weight=3.20372149754, score=0.946735 -   0.5s
# [CV] max_depth=12, min_child_weight=3.20372149754 ....................
# [CV]  max_depth=12, min_child_weight=3.20372149754, score=0.950317 -   0.5s
# [CV] max_depth=12, min_child_weight=4.68205492005 ....................
# [CV]  max_depth=12, min_child_weight=4.68205492005, score=0.901236 -   0.5s
# [CV] max_depth=12, min_child_weight=4.68205492005 ....................
# [CV]  max_depth=12, min_child_weight=4.68205492005, score=0.919851 -   0.5s
# [CV] max_depth=12, min_child_weight=4.68205492005 ....................
# [CV]  max_depth=12, min_child_weight=4.68205492005, score=0.936824 -   0.5s
# [CV] max_depth=12, min_child_weight=4.68205492005 ....................
# [CV]  max_depth=12, min_child_weight=4.68205492005, score=0.946070 -   0.5s
# [CV] max_depth=12, min_child_weight=4.68205492005 ....................
# [CV]  max_depth=12, min_child_weight=4.68205492005, score=0.955471 -   0.5s
# [CV] max_depth=12, min_child_weight=6.84255428919 ....................
# [CV]  max_depth=12, min_child_weight=6.84255428919, score=0.906867 -   0.4s
# [CV] max_depth=12, min_child_weight=6.84255428919 ....................
# [CV]  max_depth=12, min_child_weight=6.84255428919, score=0.917362 -   0.4s
# [CV] max_depth=12, min_child_weight=6.84255428919 ....................
# [CV]  max_depth=12, min_child_weight=6.84255428919, score=0.940063 -   0.4s
# [CV] max_depth=12, min_child_weight=6.84255428919 ....................
# [CV]  max_depth=12, min_child_weight=6.84255428919, score=0.949275 -   0.4s
# [CV] max_depth=12, min_child_weight=6.84255428919 ....................
# [CV]  max_depth=12, min_child_weight=6.84255428919, score=0.956739 -   0.4s
# [CV] max_depth=12, min_child_weight=10.0 .............................
# [CV] .... max_depth=12, min_child_weight=10.0, score=0.903559 -   0.3s
# [CV] max_depth=12, min_child_weight=10.0 .............................
# [CV] .... max_depth=12, min_child_weight=10.0, score=0.906776 -   0.4s
# [CV] max_depth=12, min_child_weight=10.0 .............................
# [CV] .... max_depth=12, min_child_weight=10.0, score=0.935899 -   0.4s
# [CV] max_depth=12, min_child_weight=10.0 .............................
# [CV] .... max_depth=12, min_child_weight=10.0, score=0.947258 -   1.1s
# [CV] max_depth=12, min_child_weight=10.0 .............................
# [CV] .... max_depth=12, min_child_weight=10.0, score=0.953942 -   0.7s
# [CV] max_depth=14, min_child_weight=1.5 ..............................
# [CV] ..... max_depth=14, min_child_weight=1.5, score=0.905934 -   1.4s
# [CV] max_depth=14, min_child_weight=1.5 ..............................
# [CV] ..... max_depth=14, min_child_weight=1.5, score=0.907419 -   0.6s
# [CV] max_depth=14, min_child_weight=1.5 ..............................
# [CV] ..... max_depth=14, min_child_weight=1.5, score=0.936747 -   2.0s
# [CV] max_depth=14, min_child_weight=1.5 ..............................
# [CV] ..... max_depth=14, min_child_weight=1.5, score=0.943688 -   1.1s
# [CV] max_depth=14, min_child_weight=1.5 ..............................
# [CV] ..... max_depth=14, min_child_weight=1.5, score=0.951006 -   0.6s
# [CV] max_depth=14, min_child_weight=2.19216382743 ....................
# [CV]  max_depth=14, min_child_weight=2.19216382743, score=0.902471 -   0.9s
# [CV] max_depth=14, min_child_weight=2.19216382743 ....................
# [CV]  max_depth=14, min_child_weight=2.19216382743, score=0.905668 -   0.6s
# [CV] max_depth=14, min_child_weight=2.19216382743 ....................
# [CV]  max_depth=14, min_child_weight=2.19216382743, score=0.938655 -   0.7s
# [CV] max_depth=14, min_child_weight=2.19216382743 ....................
# [CV]  max_depth=14, min_child_weight=2.19216382743, score=0.942045 -   0.7s
# [CV] max_depth=14, min_child_weight=2.19216382743 ....................
# [CV]  max_depth=14, min_child_weight=2.19216382743, score=0.952433 -   0.6s
# [CV] max_depth=14, min_child_weight=3.20372149754 ....................
# [CV]  max_depth=14, min_child_weight=3.20372149754, score=0.903283 -   0.9s
# [CV] max_depth=14, min_child_weight=3.20372149754 ....................
# [CV]  max_depth=14, min_child_weight=3.20372149754, score=0.913730 -   1.7s
# [CV] max_depth=14, min_child_weight=3.20372149754 ....................
# [CV]  max_depth=14, min_child_weight=3.20372149754, score=0.935062 -   0.7s
# [CV] max_depth=14, min_child_weight=3.20372149754 ....................
# [CV]  max_depth=14, min_child_weight=3.20372149754, score=0.946826 -   1.0s
# [CV] max_depth=14, min_child_weight=3.20372149754 ....................
# [CV]  max_depth=14, min_child_weight=3.20372149754, score=0.955265 -   0.9s
# [CV] max_depth=14, min_child_weight=4.68205492005 ....................
# [CV]  max_depth=14, min_child_weight=4.68205492005, score=0.901236 -   0.8s
# [CV] max_depth=14, min_child_weight=4.68205492005 ....................
# [CV]  max_depth=14, min_child_weight=4.68205492005, score=0.919851 -   0.7s
# [CV] max_depth=14, min_child_weight=4.68205492005 ....................
# [CV]  max_depth=14, min_child_weight=4.68205492005, score=0.936824 -   0.5s
# [CV] max_depth=14, min_child_weight=4.68205492005 ....................
# [CV]  max_depth=14, min_child_weight=4.68205492005, score=0.946070 -   0.5s
# [CV] max_depth=14, min_child_weight=4.68205492005 ....................
# [CV]  max_depth=14, min_child_weight=4.68205492005, score=0.955471 -   0.6s
# [CV] max_depth=14, min_child_weight=6.84255428919 ....................
# [CV]  max_depth=14, min_child_weight=6.84255428919, score=0.906867 -   0.4s
# [CV] max_depth=14, min_child_weight=6.84255428919 ....................
# [CV]  max_depth=14, min_child_weight=6.84255428919, score=0.917362 -   0.4s
# [CV] max_depth=14, min_child_weight=6.84255428919 ....................
# [CV]  max_depth=14, min_child_weight=6.84255428919, score=0.940063 -   0.4s
# [CV] max_depth=14, min_child_weight=6.84255428919 ....................
# [CV]  max_depth=14, min_child_weight=6.84255428919, score=0.949275 -   0.4s
# [CV] max_depth=14, min_child_weight=6.84255428919 ....................
# [CV]  max_depth=14, min_child_weight=6.84255428919, score=0.956739 -   0.4s
# [CV] max_depth=14, min_child_weight=10.0 .............................
# [CV] .... max_depth=14, min_child_weight=10.0, score=0.903559 -   0.4s
# [CV] max_depth=14, min_child_weight=10.0 .............................
# [CV] .... max_depth=14, min_child_weight=10.0, score=0.906776 -   0.4s
# [CV] max_depth=14, min_child_weight=10.0 .............................
# [CV] .... max_depth=14, min_child_weight=10.0, score=0.935899 -   0.4s
# [CV] max_depth=14, min_child_weight=10.0 .............................
# [CV] .... max_depth=14, min_child_weight=10.0, score=0.947258 -   0.4s
# [CV] max_depth=14, min_child_weight=10.0 .............................
# [CV] .... max_depth=14, min_child_weight=10.0, score=0.953942 -   0.4s
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed:  4.0min finished

# %%
plot_grid_Scores(grid)
# Out:
# <function __main__.plotgrid>

# %% [markdown]
# Here, again, it looks like anywhere between 10 to 6 for the max_depth is good as long as you have a min_child_weight with a value of aroung ~3. Scores start decreasing if max_depth goes past 10.

# %% [markdown]
# Lets try varying some of the other parameters with the 90% reduced sample space. Lets now try to adjust colsample_by_tree and subsample

# %%
#again, keep the number of estimators and learning rate the same.
model3 = XGBClassifier(seed = 3, n_estimators=100, learning_rate=0.1, colsample_bytree= 0.1)

col_sample = np.linspace(0.1, 1, 10)
subsample = np.linspace(0.6,1, 5)
#n_estim = [200]

param_grid = dict(colsample_bytree=col_sample, subsample = subsample)
grid = GridSearchCV(estimator = model3, param_grid = param_grid, scoring='average_precision',iid=False,cv=5, verbose = 15)
grid.fit(df_X.iloc[:Nrows_train], df_Y[:Nrows_train]) #10% of total dataset

# get the names of the parameters
param_names = param_grid.keys()
param_vals = [[val for val in param_grid[param_name]] for param_name in param_names]
param_val_names = {param_name:["{0}".format(val) for val in param_grid[param_name]] for param_name in param_names}
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] subsample=0.5, colsample_bytree=0.1 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.1, score=0.797691 -   0.3s
# [CV] subsample=0.5, colsample_bytree=0.1 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.1, score=0.780390 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.1 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.1, score=0.841131 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.1 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.1, score=0.823767 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.1 .............................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.5s remaining:    0.0s
# [CV] .... subsample=0.5, colsample_bytree=0.1, score=0.838887 -   0.1s
# [CV] subsample=0.625, colsample_bytree=0.1 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.1, score=0.789235 -   0.1s
# [CV] subsample=0.625, colsample_bytree=0.1 ...........................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.7s remaining:    0.0s
# [CV] .. subsample=0.625, colsample_bytree=0.1, score=0.777294 -   0.2s
# [CV] subsample=0.625, colsample_bytree=0.1 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.1, score=0.832699 -   0.1s
# [CV] subsample=0.625, colsample_bytree=0.1 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.1, score=0.841811 -   0.1s
# [CV] subsample=0.625, colsample_bytree=0.1 ...........................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    1.1s remaining:    0.0s
# [CV] .. subsample=0.625, colsample_bytree=0.1, score=0.856050 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.1 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.1, score=0.803596 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.1 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.1, score=0.787078 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.1 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.1, score=0.826380 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.1 ............................
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:    1.4s remaining:    0.0s
# [CV] ... subsample=0.75, colsample_bytree=0.1, score=0.855444 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.1 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.1, score=0.866723 -   0.1s
# [CV] subsample=0.875, colsample_bytree=0.1 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.1, score=0.783292 -   0.1s
# [CV] subsample=0.875, colsample_bytree=0.1 ...........................
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:    1.5s remaining:    0.0s
# [CV] .. subsample=0.875, colsample_bytree=0.1, score=0.808906 -   0.1s
# [CV] subsample=0.875, colsample_bytree=0.1 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.1, score=0.843354 -   0.1s
# [CV] subsample=0.875, colsample_bytree=0.1 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.1, score=0.857553 -   0.1s
# [CV] subsample=0.875, colsample_bytree=0.1 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.1, score=0.861122 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.1 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.1, score=0.810076 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.1 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.1, score=0.862228 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.1 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.1, score=0.877202 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.1 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.1, score=0.880359 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.1 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.1, score=0.853339 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.2 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.2, score=0.877639 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.2 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.2, score=0.882998 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.2 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.2, score=0.891113 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.2 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.2, score=0.905725 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.2 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.2, score=0.914991 -   0.3s
# [CV] subsample=0.625, colsample_bytree=0.2 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.2, score=0.889527 -   0.1s
# [CV] subsample=0.625, colsample_bytree=0.2 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.2, score=0.895012 -   0.1s
# [CV] subsample=0.625, colsample_bytree=0.2 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.2, score=0.891848 -   0.2s
# [CV] subsample=0.625, colsample_bytree=0.2 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.2, score=0.925326 -   0.1s
# [CV] subsample=0.625, colsample_bytree=0.2 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.2, score=0.927138 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.2 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.2, score=0.878991 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.2 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.2, score=0.900126 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.2 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.2, score=0.910265 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.2 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.2, score=0.936367 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.2 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.2, score=0.930730 -   0.1s
# [CV] subsample=0.875, colsample_bytree=0.2 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.2, score=0.879726 -   0.1s
# [CV] subsample=0.875, colsample_bytree=0.2 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.2, score=0.889015 -   0.1s
# [CV] subsample=0.875, colsample_bytree=0.2 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.2, score=0.898384 -   0.1s
# [CV] subsample=0.875, colsample_bytree=0.2 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.2, score=0.927529 -   0.1s
# [CV] subsample=0.875, colsample_bytree=0.2 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.2, score=0.924687 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.2 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.2, score=0.886480 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.2 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.2, score=0.882154 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.2 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.2, score=0.920000 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.2 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.2, score=0.925629 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.2 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.2, score=0.921638 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.3 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.3, score=0.892080 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.3 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.3, score=0.910226 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.3 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.3, score=0.915214 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.3 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.3, score=0.938000 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.3 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.3, score=0.925703 -   0.1s
# [CV] subsample=0.625, colsample_bytree=0.3 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.3, score=0.901148 -   0.1s
# [CV] subsample=0.625, colsample_bytree=0.3 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.3, score=0.897688 -   0.1s
# [CV] subsample=0.625, colsample_bytree=0.3 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.3, score=0.919581 -   0.1s
# [CV] subsample=0.625, colsample_bytree=0.3 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.3, score=0.940997 -   0.1s
# [CV] subsample=0.625, colsample_bytree=0.3 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.3, score=0.931369 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.3 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.3, score=0.890394 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.3 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.3, score=0.902886 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.3 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.3, score=0.920918 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.3 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.3, score=0.938674 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.3 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.3, score=0.940575 -   0.1s
# [CV] subsample=0.875, colsample_bytree=0.3 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.3, score=0.898146 -   0.1s
# [CV] subsample=0.875, colsample_bytree=0.3 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.3, score=0.901066 -   0.1s
# [CV] subsample=0.875, colsample_bytree=0.3 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.3, score=0.922156 -   0.1s
# [CV] subsample=0.875, colsample_bytree=0.3 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.3, score=0.938716 -   0.2s
# [CV] subsample=0.875, colsample_bytree=0.3 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.3, score=0.938738 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.3 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.3, score=0.891593 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.3 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.3, score=0.901139 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.3 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.3, score=0.931164 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.3 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.3, score=0.944221 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.3 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.3, score=0.941769 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.4 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.4, score=0.896295 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.4 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.4, score=0.901382 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.4 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.4, score=0.921987 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.4 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.4, score=0.946113 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.4 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.4, score=0.941327 -   0.1s
# [CV] subsample=0.625, colsample_bytree=0.4 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.4, score=0.894583 -   0.1s
# [CV] subsample=0.625, colsample_bytree=0.4 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.4, score=0.907799 -   0.1s
# [CV] subsample=0.625, colsample_bytree=0.4 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.4, score=0.918548 -   0.1s
# [CV] subsample=0.625, colsample_bytree=0.4 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.4, score=0.945196 -   0.1s
# [CV] subsample=0.625, colsample_bytree=0.4 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.4, score=0.941367 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.4 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.4, score=0.900877 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.4 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.4, score=0.912342 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.4 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.4, score=0.925379 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.4 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.4, score=0.951481 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.4 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.4, score=0.948533 -   0.1s
# [CV] subsample=0.875, colsample_bytree=0.4 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.4, score=0.901710 -   0.1s
# [CV] subsample=0.875, colsample_bytree=0.4 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.4, score=0.911779 -   0.1s
# [CV] subsample=0.875, colsample_bytree=0.4 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.4, score=0.931411 -   0.1s
# [CV] subsample=0.875, colsample_bytree=0.4 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.4, score=0.942839 -   0.1s
# [CV] subsample=0.875, colsample_bytree=0.4 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.4, score=0.949393 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.4 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.4, score=0.890514 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.4 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.4, score=0.903554 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.4 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.4, score=0.936237 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.4 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.4, score=0.949305 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.4 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.4, score=0.950999 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.5 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.5, score=0.892290 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.5 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.5, score=0.909063 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.5 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.5, score=0.920184 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.5 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.5, score=0.948269 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.5 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.5, score=0.951292 -   0.1s
# [CV] subsample=0.625, colsample_bytree=0.5 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.5, score=0.903553 -   0.1s
# [CV] subsample=0.625, colsample_bytree=0.5 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.5, score=0.907895 -   0.1s
# [CV] subsample=0.625, colsample_bytree=0.5 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.5, score=0.920417 -   0.1s
# [CV] subsample=0.625, colsample_bytree=0.5 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.5, score=0.953479 -   0.1s
# [CV] subsample=0.625, colsample_bytree=0.5 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.5, score=0.946932 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.5 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.5, score=0.903035 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.5 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.5, score=0.907803 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.5 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.5, score=0.928735 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.5 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.5, score=0.949112 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.5 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.5, score=0.951089 -   0.1s
# [CV] subsample=0.875, colsample_bytree=0.5 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.5, score=0.894018 -   0.1s
# [CV] subsample=0.875, colsample_bytree=0.5 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.5, score=0.908994 -   0.1s
# [CV] subsample=0.875, colsample_bytree=0.5 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.5, score=0.931398 -   0.1s
# [CV] subsample=0.875, colsample_bytree=0.5 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.5, score=0.949442 -   0.1s
# [CV] subsample=0.875, colsample_bytree=0.5 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.5, score=0.954078 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.5 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.5, score=0.885164 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.5 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.5, score=0.912262 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.5 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.5, score=0.934250 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.5 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.5, score=0.949955 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.5 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.5, score=0.948893 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.6 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.6, score=0.891518 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.6 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.6, score=0.912121 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.6 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.6, score=0.923716 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.6 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.6, score=0.949929 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.6 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.6, score=0.948870 -   0.1s
# [CV] subsample=0.625, colsample_bytree=0.6 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.6, score=0.898737 -   0.1s
# [CV] subsample=0.625, colsample_bytree=0.6 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.6, score=0.912699 -   0.1s
# [CV] subsample=0.625, colsample_bytree=0.6 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.6, score=0.925568 -   0.1s
# [CV] subsample=0.625, colsample_bytree=0.6 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.6, score=0.952053 -   0.1s
# [CV] subsample=0.625, colsample_bytree=0.6 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.6, score=0.948615 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.6 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.6, score=0.901737 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.6 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.6, score=0.905673 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.6 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.6, score=0.933509 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.6 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.6, score=0.950697 -   0.1s
# [CV] subsample=0.75, colsample_bytree=0.6 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.6, score=0.950104 -   0.1s
# [CV] subsample=0.875, colsample_bytree=0.6 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.6, score=0.890976 -   0.1s
# [CV] subsample=0.875, colsample_bytree=0.6 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.6, score=0.906978 -   0.2s
# [CV] subsample=0.875, colsample_bytree=0.6 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.6, score=0.934593 -   0.2s
# [CV] subsample=0.875, colsample_bytree=0.6 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.6, score=0.950870 -   0.2s
# [CV] subsample=0.875, colsample_bytree=0.6 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.6, score=0.955330 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.6 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.6, score=0.887605 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.6 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.6, score=0.909334 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.6 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.6, score=0.934950 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.6 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.6, score=0.947546 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.6 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.6, score=0.959994 -   0.2s
# [CV] subsample=0.5, colsample_bytree=0.7 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.7, score=0.898764 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.7 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.7, score=0.913836 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.7 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.7, score=0.924971 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.7 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.7, score=0.947811 -   0.1s
# [CV] subsample=0.5, colsample_bytree=0.7 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.7, score=0.956669 -   0.1s
# [CV] subsample=0.625, colsample_bytree=0.7 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.7, score=0.900838 -   0.2s
# [CV] subsample=0.625, colsample_bytree=0.7 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.7, score=0.915276 -   0.2s
# [CV] subsample=0.625, colsample_bytree=0.7 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.7, score=0.928151 -   0.2s
# [CV] subsample=0.625, colsample_bytree=0.7 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.7, score=0.949050 -   0.2s
# [CV] subsample=0.625, colsample_bytree=0.7 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.7, score=0.959103 -   0.2s
# [CV] subsample=0.75, colsample_bytree=0.7 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.7, score=0.903628 -   0.2s
# [CV] subsample=0.75, colsample_bytree=0.7 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.7, score=0.913958 -   0.2s
# [CV] subsample=0.75, colsample_bytree=0.7 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.7, score=0.931180 -   0.2s
# [CV] subsample=0.75, colsample_bytree=0.7 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.7, score=0.954888 -   0.2s
# [CV] subsample=0.75, colsample_bytree=0.7 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.7, score=0.947869 -   0.2s
# [CV] subsample=0.875, colsample_bytree=0.7 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.7, score=0.897753 -   0.2s
# [CV] subsample=0.875, colsample_bytree=0.7 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.7, score=0.914107 -   0.2s
# [CV] subsample=0.875, colsample_bytree=0.7 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.7, score=0.933978 -   0.2s
# [CV] subsample=0.875, colsample_bytree=0.7 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.7, score=0.949448 -   0.2s
# [CV] subsample=0.875, colsample_bytree=0.7 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.7, score=0.960137 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.7 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.7, score=0.896919 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.7 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.7, score=0.915630 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.7 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.7, score=0.938427 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.7 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.7, score=0.945512 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.7 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.7, score=0.952987 -   0.2s
# [CV] subsample=0.5, colsample_bytree=0.8 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.8, score=0.895669 -   0.2s
# [CV] subsample=0.5, colsample_bytree=0.8 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.8, score=0.910684 -   0.2s
# [CV] subsample=0.5, colsample_bytree=0.8 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.8, score=0.931466 -   0.2s
# [CV] subsample=0.5, colsample_bytree=0.8 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.8, score=0.938818 -   0.2s
# [CV] subsample=0.5, colsample_bytree=0.8 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.8, score=0.953799 -   0.2s
# [CV] subsample=0.625, colsample_bytree=0.8 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.8, score=0.902587 -   0.2s
# [CV] subsample=0.625, colsample_bytree=0.8 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.8, score=0.911393 -   0.2s
# [CV] subsample=0.625, colsample_bytree=0.8 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.8, score=0.928834 -   0.2s
# [CV] subsample=0.625, colsample_bytree=0.8 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.8, score=0.945979 -   0.2s
# [CV] subsample=0.625, colsample_bytree=0.8 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.8, score=0.953655 -   0.2s
# [CV] subsample=0.75, colsample_bytree=0.8 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.8, score=0.894638 -   0.2s
# [CV] subsample=0.75, colsample_bytree=0.8 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.8, score=0.918156 -   0.2s
# [CV] subsample=0.75, colsample_bytree=0.8 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.8, score=0.930678 -   0.2s
# [CV] subsample=0.75, colsample_bytree=0.8 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.8, score=0.951422 -   0.2s
# [CV] subsample=0.75, colsample_bytree=0.8 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.8, score=0.943548 -   0.2s
# [CV] subsample=0.875, colsample_bytree=0.8 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.8, score=0.897550 -   0.2s
# [CV] subsample=0.875, colsample_bytree=0.8 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.8, score=0.909720 -   0.2s
# [CV] subsample=0.875, colsample_bytree=0.8 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.8, score=0.934075 -   0.2s
# [CV] subsample=0.875, colsample_bytree=0.8 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.8, score=0.946850 -   0.2s
# [CV] subsample=0.875, colsample_bytree=0.8 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.8, score=0.956316 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.8 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.8, score=0.888205 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.8 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.8, score=0.916667 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.8 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.8, score=0.937554 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.8 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.8, score=0.946693 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.8 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.8, score=0.953820 -   0.2s
# [CV] subsample=0.5, colsample_bytree=0.9 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.9, score=0.895029 -   0.2s
# [CV] subsample=0.5, colsample_bytree=0.9 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.9, score=0.914366 -   0.2s
# [CV] subsample=0.5, colsample_bytree=0.9 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.9, score=0.925852 -   0.2s
# [CV] subsample=0.5, colsample_bytree=0.9 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.9, score=0.941036 -   0.2s
# [CV] subsample=0.5, colsample_bytree=0.9 .............................
# [CV] .... subsample=0.5, colsample_bytree=0.9, score=0.953292 -   0.2s
# [CV] subsample=0.625, colsample_bytree=0.9 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.9, score=0.901390 -   0.2s
# [CV] subsample=0.625, colsample_bytree=0.9 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.9, score=0.914938 -   0.2s
# [CV] subsample=0.625, colsample_bytree=0.9 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.9, score=0.931164 -   0.2s
# [CV] subsample=0.625, colsample_bytree=0.9 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.9, score=0.951206 -   0.2s
# [CV] subsample=0.625, colsample_bytree=0.9 ...........................
# [CV] .. subsample=0.625, colsample_bytree=0.9, score=0.953799 -   0.2s
# [CV] subsample=0.75, colsample_bytree=0.9 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.9, score=0.891099 -   0.2s
# [CV] subsample=0.75, colsample_bytree=0.9 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.9, score=0.917505 -   0.2s
# [CV] subsample=0.75, colsample_bytree=0.9 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.9, score=0.933200 -   0.2s
# [CV] subsample=0.75, colsample_bytree=0.9 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.9, score=0.953063 -   0.2s
# [CV] subsample=0.75, colsample_bytree=0.9 ............................
# [CV] ... subsample=0.75, colsample_bytree=0.9, score=0.948555 -   0.2s
# [CV] subsample=0.875, colsample_bytree=0.9 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.9, score=0.889630 -   0.2s
# [CV] subsample=0.875, colsample_bytree=0.9 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.9, score=0.914272 -   0.2s
# [CV] subsample=0.875, colsample_bytree=0.9 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.9, score=0.934871 -   0.2s
# [CV] subsample=0.875, colsample_bytree=0.9 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.9, score=0.946071 -   0.2s
# [CV] subsample=0.875, colsample_bytree=0.9 ...........................
# [CV] .. subsample=0.875, colsample_bytree=0.9, score=0.949504 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.9 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.9, score=0.882833 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.9 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.9, score=0.920971 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.9 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.9, score=0.935279 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.9 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.9, score=0.944714 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.9 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.9, score=0.955890 -   0.2s
# [CV] subsample=0.5, colsample_bytree=1.0 .............................
# [CV] .... subsample=0.5, colsample_bytree=1.0, score=0.894796 -   0.2s
# [CV] subsample=0.5, colsample_bytree=1.0 .............................
# [CV] .... subsample=0.5, colsample_bytree=1.0, score=0.912719 -   0.2s
# [CV] subsample=0.5, colsample_bytree=1.0 .............................
# [CV] .... subsample=0.5, colsample_bytree=1.0, score=0.936412 -   0.2s
# [CV] subsample=0.5, colsample_bytree=1.0 .............................
# [CV] .... subsample=0.5, colsample_bytree=1.0, score=0.946662 -   0.2s
# [CV] subsample=0.5, colsample_bytree=1.0 .............................
# [CV] .... subsample=0.5, colsample_bytree=1.0, score=0.941325 -   0.2s
# [CV] subsample=0.625, colsample_bytree=1.0 ...........................
# [CV] .. subsample=0.625, colsample_bytree=1.0, score=0.907848 -   0.2s
# [CV] subsample=0.625, colsample_bytree=1.0 ...........................
# [CV] .. subsample=0.625, colsample_bytree=1.0, score=0.914293 -   0.2s
# [CV] subsample=0.625, colsample_bytree=1.0 ...........................
# [CV] .. subsample=0.625, colsample_bytree=1.0, score=0.927760 -   0.2s
# [CV] subsample=0.625, colsample_bytree=1.0 ...........................
# [CV] .. subsample=0.625, colsample_bytree=1.0, score=0.949010 -   0.2s
# [CV] subsample=0.625, colsample_bytree=1.0 ...........................
# [CV] .. subsample=0.625, colsample_bytree=1.0, score=0.948979 -   0.2s
# [CV] subsample=0.75, colsample_bytree=1.0 ............................
# [CV] ... subsample=0.75, colsample_bytree=1.0, score=0.895887 -   0.2s
# [CV] subsample=0.75, colsample_bytree=1.0 ............................
# [CV] ... subsample=0.75, colsample_bytree=1.0, score=0.913977 -   0.2s
# [CV] subsample=0.75, colsample_bytree=1.0 ............................
# [CV] ... subsample=0.75, colsample_bytree=1.0, score=0.934345 -   0.2s
# [CV] subsample=0.75, colsample_bytree=1.0 ............................
# [CV] ... subsample=0.75, colsample_bytree=1.0, score=0.948256 -   0.3s
# [CV] subsample=0.75, colsample_bytree=1.0 ............................
# [CV] ... subsample=0.75, colsample_bytree=1.0, score=0.951682 -   0.2s
# [CV] subsample=0.875, colsample_bytree=1.0 ...........................
# [CV] .. subsample=0.875, colsample_bytree=1.0, score=0.892134 -   0.2s
# [CV] subsample=0.875, colsample_bytree=1.0 ...........................
# [CV] .. subsample=0.875, colsample_bytree=1.0, score=0.916883 -   0.2s
# [CV] subsample=0.875, colsample_bytree=1.0 ...........................
# [CV] .. subsample=0.875, colsample_bytree=1.0, score=0.935284 -   0.2s
# [CV] subsample=0.875, colsample_bytree=1.0 ...........................
# [CV] .. subsample=0.875, colsample_bytree=1.0, score=0.947082 -   0.2s
# [CV] subsample=0.875, colsample_bytree=1.0 ...........................
# [CV] .. subsample=0.875, colsample_bytree=1.0, score=0.954041 -   0.2s
# [CV] subsample=1.0, colsample_bytree=1.0 .............................
# [CV] .... subsample=1.0, colsample_bytree=1.0, score=0.881948 -   0.3s
# [CV] subsample=1.0, colsample_bytree=1.0 .............................
# [CV] .... subsample=1.0, colsample_bytree=1.0, score=0.916673 -   0.3s
# [CV] subsample=1.0, colsample_bytree=1.0 .............................
# [CV] .... subsample=1.0, colsample_bytree=1.0, score=0.937065 -   0.2s
# [CV] subsample=1.0, colsample_bytree=1.0 .............................
# [CV] .... subsample=1.0, colsample_bytree=1.0, score=0.945705 -   0.2s
# [CV] subsample=1.0, colsample_bytree=1.0 .............................
# [CV] .... subsample=1.0, colsample_bytree=1.0, score=0.957338 -   0.3s
# [Parallel(n_jobs=1)]: Done 250 out of 250 | elapsed:   37.8s finished

# %%
plot_grid_Scores(grid)
# Out:
# <function __main__.plotgrid>

# %% [markdown]
# Try with f1 score, since accuracy might not be a good representation since this dataset has about a ~2 to 1 ratio of unstable to stable.

# %%
#again, keep the number of estimators and learning rate the same.
model3 = XGBClassifier(seed = 3, n_estimators=100, learning_rate=0.1, colsample_bytree= 0.1)

col_sample = np.linspace(0.1, 1, 10)
subsample = np.linspace(0.7,1, 4)
#n_estim = [200]

param_grid = dict(colsample_bytree=col_sample, subsample = subsample)
grid = GridSearchCV(estimator = model3, param_grid = param_grid, scoring='f1',iid=False,cv=5, verbose = 15)
grid.fit(df_X.iloc[:Nrows_train], df_Y[:Nrows_train]) #10% of total dataset

# get the names of the parameters
param_names = param_grid.keys()
param_vals = [[val for val in param_grid[param_name]] for param_name in param_names]
param_val_names = {param_name:["{0}".format(val) for val in param_grid[param_name]] for param_name in param_names}
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV] subsample=0.7, colsample_bytree=0.1 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.1, score=0.729508 -   0.6s
# [CV] subsample=0.7, colsample_bytree=0.1 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.1, score=0.689956 -   0.1s
# [CV] subsample=0.7, colsample_bytree=0.1 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.1, score=0.769874 -   0.1s
# [CV] subsample=0.7, colsample_bytree=0.1 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.1, score=0.731915 -   0.1s
# [CV] subsample=0.7, colsample_bytree=0.1 .............................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.8s remaining:    0.0s
# [CV] .... subsample=0.7, colsample_bytree=0.1, score=0.781513 -   0.1s
# [CV] subsample=0.8, colsample_bytree=0.1 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.1, score=0.719008 -   0.1s
# [CV] subsample=0.8, colsample_bytree=0.1 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.1, score=0.711864 -   0.1s
# [CV] subsample=0.8, colsample_bytree=0.1 .............................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    1.0s remaining:    0.0s
# [CV] .... subsample=0.8, colsample_bytree=0.1, score=0.781116 -   0.1s
# [CV] subsample=0.8, colsample_bytree=0.1 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.1, score=0.728814 -   0.1s
# [CV] subsample=0.8, colsample_bytree=0.1 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.1, score=0.781116 -   0.1s
# [CV] subsample=0.9, colsample_bytree=0.1 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.1, score=0.728814 -   0.1s
# [CV] subsample=0.9, colsample_bytree=0.1 .............................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:    1.3s remaining:    0.0s
# [CV] .... subsample=0.9, colsample_bytree=0.1, score=0.709957 -   0.1s
# [CV] subsample=0.9, colsample_bytree=0.1 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.1, score=0.758621 -   0.1s
# [CV] subsample=0.9, colsample_bytree=0.1 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.1, score=0.714286 -   0.1s
# [CV] subsample=0.9, colsample_bytree=0.1 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.1, score=0.801688 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.1 .............................
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:    1.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:    1.5s remaining:    0.0s
# [CV] .... subsample=1.0, colsample_bytree=0.1, score=0.740741 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.1 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.1, score=0.760684 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.1 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.1, score=0.781893 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.1 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.1, score=0.800000 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.1 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.1, score=0.784483 -   0.1s
# [CV] subsample=0.7, colsample_bytree=0.2 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.2, score=0.753036 -   0.1s
# [CV] subsample=0.7, colsample_bytree=0.2 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.2, score=0.810127 -   0.1s
# [CV] subsample=0.7, colsample_bytree=0.2 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.2, score=0.813559 -   0.1s
# [CV] subsample=0.7, colsample_bytree=0.2 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.2, score=0.817021 -   0.1s
# [CV] subsample=0.7, colsample_bytree=0.2 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.2, score=0.845528 -   0.1s
# [CV] subsample=0.8, colsample_bytree=0.2 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.2, score=0.787149 -   0.4s
# [CV] subsample=0.8, colsample_bytree=0.2 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.2, score=0.788136 -   0.1s
# [CV] subsample=0.8, colsample_bytree=0.2 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.2, score=0.800000 -   0.1s
# [CV] subsample=0.8, colsample_bytree=0.2 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.2, score=0.831933 -   0.5s
# [CV] subsample=0.8, colsample_bytree=0.2 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.2, score=0.841667 -   0.1s
# [CV] subsample=0.9, colsample_bytree=0.2 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.2, score=0.792000 -   0.1s
# [CV] subsample=0.9, colsample_bytree=0.2 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.2, score=0.793249 -   0.1s
# [CV] subsample=0.9, colsample_bytree=0.2 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.2, score=0.810127 -   0.6s
# [CV] subsample=0.9, colsample_bytree=0.2 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.2, score=0.852321 -   0.1s
# [CV] subsample=0.9, colsample_bytree=0.2 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.2, score=0.852459 -   0.5s
# [CV] subsample=1.0, colsample_bytree=0.2 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.2, score=0.776471 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.2 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.2, score=0.805085 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.2 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.2, score=0.836066 -   0.5s
# [CV] subsample=1.0, colsample_bytree=0.2 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.2, score=0.827004 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.2 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.2, score=0.837398 -   0.1s
# [CV] subsample=0.7, colsample_bytree=0.3 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.3, score=0.801619 -   0.3s
# [CV] subsample=0.7, colsample_bytree=0.3 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.3, score=0.820513 -   0.1s
# [CV] subsample=0.7, colsample_bytree=0.3 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.3, score=0.838174 -   0.2s
# [CV] subsample=0.7, colsample_bytree=0.3 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.3, score=0.842553 -   0.1s
# [CV] subsample=0.7, colsample_bytree=0.3 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.3, score=0.867769 -   0.1s
# [CV] subsample=0.8, colsample_bytree=0.3 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.3, score=0.780876 -   0.1s
# [CV] subsample=0.8, colsample_bytree=0.3 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.3, score=0.801724 -   0.1s
# [CV] subsample=0.8, colsample_bytree=0.3 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.3, score=0.853556 -   0.1s
# [CV] subsample=0.8, colsample_bytree=0.3 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.3, score=0.857143 -   0.1s
# [CV] subsample=0.8, colsample_bytree=0.3 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.3, score=0.860656 -   0.2s
# [CV] subsample=0.9, colsample_bytree=0.3 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.3, score=0.801587 -   0.1s
# [CV] subsample=0.9, colsample_bytree=0.3 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.3, score=0.806723 -   0.1s
# [CV] subsample=0.9, colsample_bytree=0.3 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.3, score=0.814815 -   0.1s
# [CV] subsample=0.9, colsample_bytree=0.3 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.3, score=0.861925 -   0.5s
# [CV] subsample=0.9, colsample_bytree=0.3 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.3, score=0.866667 -   0.5s
# [CV] subsample=1.0, colsample_bytree=0.3 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.3, score=0.803150 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.3 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.3, score=0.818565 -   0.3s
# [CV] subsample=1.0, colsample_bytree=0.3 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.3, score=0.838174 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.3 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.3, score=0.871369 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.3 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.3, score=0.870293 -   0.1s
# [CV] subsample=0.7, colsample_bytree=0.4 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.4, score=0.806452 -   0.1s
# [CV] subsample=0.7, colsample_bytree=0.4 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.4, score=0.825000 -   0.1s
# [CV] subsample=0.7, colsample_bytree=0.4 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.4, score=0.835443 -   0.1s
# [CV] subsample=0.7, colsample_bytree=0.4 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.4, score=0.853556 -   0.1s
# [CV] subsample=0.7, colsample_bytree=0.4 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.4, score=0.872428 -   0.2s
# [CV] subsample=0.8, colsample_bytree=0.4 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.4, score=0.798354 -   0.1s
# [CV] subsample=0.8, colsample_bytree=0.4 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.4, score=0.823529 -   0.2s
# [CV] subsample=0.8, colsample_bytree=0.4 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.4, score=0.813559 -   0.1s
# [CV] subsample=0.8, colsample_bytree=0.4 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.4, score=0.858333 -   0.1s
# [CV] subsample=0.8, colsample_bytree=0.4 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.4, score=0.872428 -   0.1s
# [CV] subsample=0.9, colsample_bytree=0.4 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.4, score=0.816000 -   0.2s
# [CV] subsample=0.9, colsample_bytree=0.4 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.4, score=0.842975 -   0.1s
# [CV] subsample=0.9, colsample_bytree=0.4 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.4, score=0.805085 -   0.1s
# [CV] subsample=0.9, colsample_bytree=0.4 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.4, score=0.880658 -   0.1s
# [CV] subsample=0.9, colsample_bytree=0.4 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.4, score=0.871795 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.4 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.4, score=0.817460 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.4 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.4, score=0.831933 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.4 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.4, score=0.830508 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.4 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.4, score=0.871369 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.4 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.4, score=0.872428 -   0.1s
# [CV] subsample=0.7, colsample_bytree=0.5 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.5, score=0.803213 -   0.2s
# [CV] subsample=0.7, colsample_bytree=0.5 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.5, score=0.816667 -   0.1s
# [CV] subsample=0.7, colsample_bytree=0.5 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.5, score=0.847458 -   0.2s
# [CV] subsample=0.7, colsample_bytree=0.5 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.5, score=0.863071 -   0.1s
# [CV] subsample=0.7, colsample_bytree=0.5 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.5, score=0.881633 -   0.2s
# [CV] subsample=0.8, colsample_bytree=0.5 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.5, score=0.814815 -   0.1s
# [CV] subsample=0.8, colsample_bytree=0.5 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.5, score=0.827004 -   0.2s
# [CV] subsample=0.8, colsample_bytree=0.5 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.5, score=0.834043 -   0.1s
# [CV] subsample=0.8, colsample_bytree=0.5 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.5, score=0.875000 -   0.2s
# [CV] subsample=0.8, colsample_bytree=0.5 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.5, score=0.875000 -   0.1s
# [CV] subsample=0.9, colsample_bytree=0.5 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.5, score=0.824000 -   0.2s
# [CV] subsample=0.9, colsample_bytree=0.5 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.5, score=0.838174 -   0.2s
# [CV] subsample=0.9, colsample_bytree=0.5 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.5, score=0.836820 -   0.2s
# [CV] subsample=0.9, colsample_bytree=0.5 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.5, score=0.852459 -   0.1s
# [CV] subsample=0.9, colsample_bytree=0.5 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.5, score=0.877049 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.5 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.5, score=0.827869 -   0.1s
# [CV] subsample=1.0, colsample_bytree=0.5 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.5, score=0.813559 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.5 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.5, score=0.827004 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.5 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.5, score=0.875000 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.5 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.5, score=0.885246 -   0.2s
# [CV] subsample=0.7, colsample_bytree=0.6 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.6, score=0.811475 -   0.2s
# [CV] subsample=0.7, colsample_bytree=0.6 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.6, score=0.831933 -   0.4s
# [CV] subsample=0.7, colsample_bytree=0.6 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.6, score=0.842553 -   0.2s
# [CV] subsample=0.7, colsample_bytree=0.6 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.6, score=0.863071 -   0.2s
# [CV] subsample=0.7, colsample_bytree=0.6 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.6, score=0.891566 -   0.2s
# [CV] subsample=0.8, colsample_bytree=0.6 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.6, score=0.809717 -   0.3s
# [CV] subsample=0.8, colsample_bytree=0.6 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.6, score=0.815126 -   0.2s
# [CV] subsample=0.8, colsample_bytree=0.6 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.6, score=0.847458 -   0.2s
# [CV] subsample=0.8, colsample_bytree=0.6 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.6, score=0.858333 -   0.3s
# [CV] subsample=0.8, colsample_bytree=0.6 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.6, score=0.890756 -   0.2s
# [CV] subsample=0.9, colsample_bytree=0.6 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.6, score=0.813008 -   0.3s
# [CV] subsample=0.9, colsample_bytree=0.6 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.6, score=0.836820 -   0.2s
# [CV] subsample=0.9, colsample_bytree=0.6 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.6, score=0.835443 -   0.2s
# [CV] subsample=0.9, colsample_bytree=0.6 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.6, score=0.870293 -   0.3s
# [CV] subsample=0.9, colsample_bytree=0.6 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.6, score=0.888889 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.6 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.6, score=0.813008 -   0.3s
# [CV] subsample=1.0, colsample_bytree=0.6 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.6, score=0.833333 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.6 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.6, score=0.835443 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.6 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.6, score=0.871369 -   0.4s
# [CV] subsample=1.0, colsample_bytree=0.6 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.6, score=0.895397 -   0.2s
# [CV] subsample=0.7, colsample_bytree=0.7 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.7, score=0.806452 -   0.3s
# [CV] subsample=0.7, colsample_bytree=0.7 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.7, score=0.820084 -   0.2s
# [CV] subsample=0.7, colsample_bytree=0.7 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.7, score=0.835443 -   0.2s
# [CV] subsample=0.7, colsample_bytree=0.7 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.7, score=0.845188 -   0.3s
# [CV] subsample=0.7, colsample_bytree=0.7 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.7, score=0.873469 -   0.2s
# [CV] subsample=0.8, colsample_bytree=0.7 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.7, score=0.811475 -   0.3s
# [CV] subsample=0.8, colsample_bytree=0.7 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.7, score=0.823529 -   0.2s
# [CV] subsample=0.8, colsample_bytree=0.7 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.7, score=0.846154 -   0.2s
# [CV] subsample=0.8, colsample_bytree=0.7 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.7, score=0.865546 -   0.3s
# [CV] subsample=0.8, colsample_bytree=0.7 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.7, score=0.884298 -   0.2s
# [CV] subsample=0.9, colsample_bytree=0.7 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.7, score=0.817814 -   0.4s
# [CV] subsample=0.9, colsample_bytree=0.7 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.7, score=0.828452 -   0.2s
# [CV] subsample=0.9, colsample_bytree=0.7 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.7, score=0.818565 -   0.3s
# [CV] subsample=0.9, colsample_bytree=0.7 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.7, score=0.860759 -   0.2s
# [CV] subsample=0.9, colsample_bytree=0.7 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.7, score=0.872428 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.7 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.7, score=0.840816 -   0.3s
# [CV] subsample=1.0, colsample_bytree=0.7 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.7, score=0.843882 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.7 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.7, score=0.827004 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.7 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.7, score=0.863071 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.7 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.7, score=0.876033 -   0.2s
# [CV] subsample=0.7, colsample_bytree=0.8 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.8, score=0.808163 -   0.2s
# [CV] subsample=0.7, colsample_bytree=0.8 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.8, score=0.830508 -   0.2s
# [CV] subsample=0.7, colsample_bytree=0.8 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.8, score=0.847458 -   0.8s
# [CV] subsample=0.7, colsample_bytree=0.8 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.8, score=0.861925 -   0.5s
# [CV] subsample=0.7, colsample_bytree=0.8 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.8, score=0.876033 -   0.2s
# [CV] subsample=0.8, colsample_bytree=0.8 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.8, score=0.811475 -   0.5s
# [CV] subsample=0.8, colsample_bytree=0.8 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.8, score=0.843882 -   0.2s
# [CV] subsample=0.8, colsample_bytree=0.8 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.8, score=0.831933 -   0.2s
# [CV] subsample=0.8, colsample_bytree=0.8 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.8, score=0.866667 -   0.2s
# [CV] subsample=0.8, colsample_bytree=0.8 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.8, score=0.883333 -   0.2s
# [CV] subsample=0.9, colsample_bytree=0.8 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.8, score=0.813278 -   0.2s
# [CV] subsample=0.9, colsample_bytree=0.8 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.8, score=0.822034 -   0.5s
# [CV] subsample=0.9, colsample_bytree=0.8 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.8, score=0.835443 -   0.8s
# [CV] subsample=0.9, colsample_bytree=0.8 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.8, score=0.852321 -   0.2s
# [CV] subsample=0.9, colsample_bytree=0.8 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.8, score=0.878661 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.8 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.8, score=0.829268 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.8 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.8, score=0.840336 -   0.6s
# [CV] subsample=1.0, colsample_bytree=0.8 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.8, score=0.831933 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.8 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.8, score=0.854772 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.8 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.8, score=0.879668 -   0.3s
# [CV] subsample=0.7, colsample_bytree=0.9 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.9, score=0.828685 -   0.3s
# [CV] subsample=0.7, colsample_bytree=0.9 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.9, score=0.817021 -   0.3s
# [CV] subsample=0.7, colsample_bytree=0.9 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.9, score=0.829060 -   0.2s
# [CV] subsample=0.7, colsample_bytree=0.9 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.9, score=0.847458 -   0.2s
# [CV] subsample=0.7, colsample_bytree=0.9 .............................
# [CV] .... subsample=0.7, colsample_bytree=0.9, score=0.877049 -   0.2s
# [CV] subsample=0.8, colsample_bytree=0.9 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.9, score=0.821138 -   0.2s
# [CV] subsample=0.8, colsample_bytree=0.9 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.9, score=0.820513 -   0.6s
# [CV] subsample=0.8, colsample_bytree=0.9 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.9, score=0.834043 -   0.3s
# [CV] subsample=0.8, colsample_bytree=0.9 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.9, score=0.870293 -   0.6s
# [CV] subsample=0.8, colsample_bytree=0.9 .............................
# [CV] .... subsample=0.8, colsample_bytree=0.9, score=0.892562 -   0.3s
# [CV] subsample=0.9, colsample_bytree=0.9 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.9, score=0.811475 -   0.6s
# [CV] subsample=0.9, colsample_bytree=0.9 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.9, score=0.815451 -   0.8s
# [CV] subsample=0.9, colsample_bytree=0.9 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.9, score=0.834043 -   0.5s
# [CV] subsample=0.9, colsample_bytree=0.9 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.9, score=0.857143 -   0.2s
# [CV] subsample=0.9, colsample_bytree=0.9 .............................
# [CV] .... subsample=0.9, colsample_bytree=0.9, score=0.887029 -   0.3s
# [CV] subsample=1.0, colsample_bytree=0.9 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.9, score=0.814815 -   0.3s
# [CV] subsample=1.0, colsample_bytree=0.9 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.9, score=0.845188 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.9 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.9, score=0.821577 -   0.3s
# [CV] subsample=1.0, colsample_bytree=0.9 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.9, score=0.861925 -   0.2s
# [CV] subsample=1.0, colsample_bytree=0.9 .............................
# [CV] .... subsample=1.0, colsample_bytree=0.9, score=0.880658 -   0.3s
# [CV] subsample=0.7, colsample_bytree=1.0 .............................
# [CV] .... subsample=0.7, colsample_bytree=1.0, score=0.819672 -   0.7s
# [CV] subsample=0.7, colsample_bytree=1.0 .............................
# [CV] .... subsample=0.7, colsample_bytree=1.0, score=0.813559 -   0.3s
# [CV] subsample=0.7, colsample_bytree=1.0 .............................
# [CV] .... subsample=0.7, colsample_bytree=1.0, score=0.840336 -   0.3s
# [CV] subsample=0.7, colsample_bytree=1.0 .............................
# [CV] .... subsample=0.7, colsample_bytree=1.0, score=0.840336 -   0.3s
# [CV] subsample=0.7, colsample_bytree=1.0 .............................
# [CV] .... subsample=0.7, colsample_bytree=1.0, score=0.878049 -   0.5s
# [CV] subsample=0.8, colsample_bytree=1.0 .............................
# [CV] .... subsample=0.8, colsample_bytree=1.0, score=0.821138 -   0.3s
# [CV] subsample=0.8, colsample_bytree=1.0 .............................
# [CV] .... subsample=0.8, colsample_bytree=1.0, score=0.806723 -   0.3s
# [CV] subsample=0.8, colsample_bytree=1.0 .............................
# [CV] .... subsample=0.8, colsample_bytree=1.0, score=0.838983 -   0.2s
# [CV] subsample=0.8, colsample_bytree=1.0 .............................
# [CV] .... subsample=0.8, colsample_bytree=1.0, score=0.871369 -   0.5s
# [CV] subsample=0.8, colsample_bytree=1.0 .............................
# [CV] .... subsample=0.8, colsample_bytree=1.0, score=0.892562 -   0.3s
# [CV] subsample=0.9, colsample_bytree=1.0 .............................
# [CV] .... subsample=0.9, colsample_bytree=1.0, score=0.826446 -   0.3s
# [CV] subsample=0.9, colsample_bytree=1.0 .............................
# [CV] .... subsample=0.9, colsample_bytree=1.0, score=0.814815 -   0.5s
# [CV] subsample=0.9, colsample_bytree=1.0 .............................
# [CV] .... subsample=0.9, colsample_bytree=1.0, score=0.843882 -   0.3s
# [CV] subsample=0.9, colsample_bytree=1.0 .............................
# [CV] .... subsample=0.9, colsample_bytree=1.0, score=0.868852 -   0.3s
# [CV] subsample=0.9, colsample_bytree=1.0 .............................
# [CV] .... subsample=0.9, colsample_bytree=1.0, score=0.887967 -   0.3s
# [CV] subsample=1.0, colsample_bytree=1.0 .............................
# [CV] .... subsample=1.0, colsample_bytree=1.0, score=0.818182 -   0.3s
# [CV] subsample=1.0, colsample_bytree=1.0 .............................
# [CV] .... subsample=1.0, colsample_bytree=1.0, score=0.830508 -   0.3s
# [CV] subsample=1.0, colsample_bytree=1.0 .............................
# [CV] .... subsample=1.0, colsample_bytree=1.0, score=0.825000 -   0.3s
# [CV] subsample=1.0, colsample_bytree=1.0 .............................
# [CV] .... subsample=1.0, colsample_bytree=1.0, score=0.852321 -   0.3s
# [CV] subsample=1.0, colsample_bytree=1.0 .............................
# [CV] .... subsample=1.0, colsample_bytree=1.0, score=0.896266 -   0.5s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:   46.0s finished

# %%
def plot_grid_Scores(grid):
    #plot map of performance across the parameter space

    # get the scores and values for the sliders
    scores = np.fabs([x[1] for x in grid.grid_scores_])
    vmin = np.min(scores)
    vmax = np.max(scores)
    mean = np.mean(scores)
    step = (vmax-vmin)/100.

    widgets.interact(plotgrid, grid=fixed(grid), vmin=FloatSlider(min=vmin, max=vmax, step=step, value=vmin), 
                 vmax=FloatSlider(min=vmin, max=vmax, step=step, value=vmax), 
                 midpoint=FloatSlider(min=vmin, max=vmax, step=step, value=mean))

# %%
plot_grid_Scores(grid)

# %% [markdown]
# Now try varying number of estimators and learning rate on the smaller dataset before we scale up. This assumes that the same paramters that work with a small dataset will still be bale to produce similar scores on the larger dataset.

# %%
model3 = XGBClassifier(seed = 3, colsample_bytree= 0.8)
n_estimators = [100,200,400,800]
learning_rate = np.logspace(-2,.1,5)
param_grid = dict(n_estimators = n_estimators, learning_rate = learning_rate)
grid = GridSearchCV(estimator = model3, param_grid = param_grid, scoring='average_precision',iid=False,cv=5, verbose = 15)
grid.fit(df_X.iloc[:Nrows_train], df_Y[:Nrows_train]) #10% of total dataset

# get the names of the parameters
param_names = param_grid.keys()
param_vals = [[val for val in param_grid[param_name]] for param_name in param_names]
param_val_names = {param_name:["{0}".format(val) for val in param_grid[param_name]] for param_name in param_names}
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] n_estimators=100, learning_rate=0.01 ............................
# [CV] ... n_estimators=100, learning_rate=0.01, score=0.839841 -   0.4s
# [CV] n_estimators=100, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [CV] ... n_estimators=100, learning_rate=0.01, score=0.816850 -   0.3s
# [CV] n_estimators=100, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.7s remaining:    0.0s
# [CV] ... n_estimators=100, learning_rate=0.01, score=0.872310 -   0.3s
# [CV] n_estimators=100, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.9s remaining:    0.0s
# [CV] ... n_estimators=100, learning_rate=0.01, score=0.925233 -   0.3s
# [CV] n_estimators=100, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    1.3s remaining:    0.0s
# [CV] ... n_estimators=100, learning_rate=0.01, score=0.894537 -   0.3s
# [CV] n_estimators=200, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    1.5s remaining:    0.0s
# [CV] ... n_estimators=200, learning_rate=0.01, score=0.854920 -   0.5s
# [CV] n_estimators=200, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    2.1s remaining:    0.0s
# [CV] ... n_estimators=200, learning_rate=0.01, score=0.854256 -   0.9s
# [CV] n_estimators=200, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    3.0s remaining:    0.0s
# [CV] ... n_estimators=200, learning_rate=0.01, score=0.897518 -   0.5s
# [CV] n_estimators=200, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    3.5s remaining:    0.0s
# [CV] ... n_estimators=200, learning_rate=0.01, score=0.935382 -   0.5s
# [CV] n_estimators=200, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    4.0s remaining:    0.0s
# [CV] ... n_estimators=200, learning_rate=0.01, score=0.923999 -   0.9s
# [CV] n_estimators=400, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    4.9s remaining:    0.0s
# [CV] ... n_estimators=400, learning_rate=0.01, score=0.870371 -   1.5s
# [CV] n_estimators=400, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:    6.4s remaining:    0.0s
# [CV] ... n_estimators=400, learning_rate=0.01, score=0.890198 -   1.0s
# [CV] n_estimators=400, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    7.3s remaining:    0.0s
# [CV] ... n_estimators=400, learning_rate=0.01, score=0.917569 -   1.8s
# [CV] n_estimators=400, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:    9.2s remaining:    0.0s
# [CV] ... n_estimators=400, learning_rate=0.01, score=0.943540 -   1.5s
# [CV] n_estimators=400, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:   10.7s remaining:    0.0s
# [CV] ... n_estimators=400, learning_rate=0.01, score=0.947179 -   0.9s
# [CV] n_estimators=800, learning_rate=0.01 ............................
# [CV] ... n_estimators=800, learning_rate=0.01, score=0.885050 -   3.6s
# [CV] n_estimators=800, learning_rate=0.01 ............................
# [CV] ... n_estimators=800, learning_rate=0.01, score=0.914162 -   1.8s
# [CV] n_estimators=800, learning_rate=0.01 ............................
# [CV] ... n_estimators=800, learning_rate=0.01, score=0.934147 -   2.2s
# [CV] n_estimators=800, learning_rate=0.01 ............................
# [CV] ... n_estimators=800, learning_rate=0.01, score=0.947663 -   1.7s
# [CV] n_estimators=800, learning_rate=0.01 ............................
# [CV] ... n_estimators=800, learning_rate=0.01, score=0.954169 -   1.6s
# [CV] n_estimators=100, learning_rate=0.0334965439158 .................
# [CV]  n_estimators=100, learning_rate=0.0334965439158, score=0.861340 -   0.2s
# [CV] n_estimators=100, learning_rate=0.0334965439158 .................
# [CV]  n_estimators=100, learning_rate=0.0334965439158, score=0.878998 -   0.2s
# [CV] n_estimators=100, learning_rate=0.0334965439158 .................
# [CV]  n_estimators=100, learning_rate=0.0334965439158, score=0.913523 -   0.3s
# [CV] n_estimators=100, learning_rate=0.0334965439158 .................
# [CV]  n_estimators=100, learning_rate=0.0334965439158, score=0.941152 -   0.2s
# [CV] n_estimators=100, learning_rate=0.0334965439158 .................
# [CV]  n_estimators=100, learning_rate=0.0334965439158, score=0.939182 -   0.3s
# [CV] n_estimators=200, learning_rate=0.0334965439158 .................
# [CV]  n_estimators=200, learning_rate=0.0334965439158, score=0.877565 -   0.4s
# [CV] n_estimators=200, learning_rate=0.0334965439158 .................
# [CV]  n_estimators=200, learning_rate=0.0334965439158, score=0.910079 -   0.4s
# [CV] n_estimators=200, learning_rate=0.0334965439158 .................
# [CV]  n_estimators=200, learning_rate=0.0334965439158, score=0.932620 -   0.4s
# [CV] n_estimators=200, learning_rate=0.0334965439158 .................
# [CV]  n_estimators=200, learning_rate=0.0334965439158, score=0.945445 -   0.4s
# [CV] n_estimators=200, learning_rate=0.0334965439158 .................
# [CV]  n_estimators=200, learning_rate=0.0334965439158, score=0.954112 -   0.4s
# [CV] n_estimators=400, learning_rate=0.0334965439158 .................
# [CV]  n_estimators=400, learning_rate=0.0334965439158, score=0.889320 -   0.8s
# [CV] n_estimators=400, learning_rate=0.0334965439158 .................
# [CV]  n_estimators=400, learning_rate=0.0334965439158, score=0.914451 -   0.8s
# [CV] n_estimators=400, learning_rate=0.0334965439158 .................
# [CV]  n_estimators=400, learning_rate=0.0334965439158, score=0.935929 -   0.8s
# [CV] n_estimators=400, learning_rate=0.0334965439158 .................
# [CV]  n_estimators=400, learning_rate=0.0334965439158, score=0.946772 -   0.8s
# [CV] n_estimators=400, learning_rate=0.0334965439158 .................
# [CV]  n_estimators=400, learning_rate=0.0334965439158, score=0.954907 -   0.8s
# [CV] n_estimators=800, learning_rate=0.0334965439158 .................
# [CV]  n_estimators=800, learning_rate=0.0334965439158, score=0.890350 -   1.5s
# [CV] n_estimators=800, learning_rate=0.0334965439158 .................
# [CV]  n_estimators=800, learning_rate=0.0334965439158, score=0.913398 -   1.6s
# [CV] n_estimators=800, learning_rate=0.0334965439158 .................
# [CV]  n_estimators=800, learning_rate=0.0334965439158, score=0.934737 -   1.5s
# [CV] n_estimators=800, learning_rate=0.0334965439158 .................
# [CV]  n_estimators=800, learning_rate=0.0334965439158, score=0.949680 -   1.7s
# [CV] n_estimators=800, learning_rate=0.0334965439158 .................
# [CV]  n_estimators=800, learning_rate=0.0334965439158, score=0.955557 -   1.5s
# [CV] n_estimators=100, learning_rate=0.11220184543 ...................
# [CV]  n_estimators=100, learning_rate=0.11220184543, score=0.887571 -   0.2s
# [CV] n_estimators=100, learning_rate=0.11220184543 ...................
# [CV]  n_estimators=100, learning_rate=0.11220184543, score=0.917218 -   0.2s
# [CV] n_estimators=100, learning_rate=0.11220184543 ...................
# [CV]  n_estimators=100, learning_rate=0.11220184543, score=0.936246 -   0.2s
# [CV] n_estimators=100, learning_rate=0.11220184543 ...................
# [CV]  n_estimators=100, learning_rate=0.11220184543, score=0.947260 -   0.2s
# [CV] n_estimators=100, learning_rate=0.11220184543 ...................
# [CV]  n_estimators=100, learning_rate=0.11220184543, score=0.954848 -   0.3s
# [CV] n_estimators=200, learning_rate=0.11220184543 ...................
# [CV]  n_estimators=200, learning_rate=0.11220184543, score=0.888488 -   0.4s
# [CV] n_estimators=200, learning_rate=0.11220184543 ...................
# [CV]  n_estimators=200, learning_rate=0.11220184543, score=0.913617 -   0.4s
# [CV] n_estimators=200, learning_rate=0.11220184543 ...................
# [CV]  n_estimators=200, learning_rate=0.11220184543, score=0.938345 -   0.4s
# [CV] n_estimators=200, learning_rate=0.11220184543 ...................
# [CV]  n_estimators=200, learning_rate=0.11220184543, score=0.948126 -   0.5s
# [CV] n_estimators=200, learning_rate=0.11220184543 ...................
# [CV]  n_estimators=200, learning_rate=0.11220184543, score=0.957132 -   0.6s
# [CV] n_estimators=400, learning_rate=0.11220184543 ...................
# [CV]  n_estimators=400, learning_rate=0.11220184543, score=0.892269 -   1.1s
# [CV] n_estimators=400, learning_rate=0.11220184543 ...................
# [CV]  n_estimators=400, learning_rate=0.11220184543, score=0.916938 -   1.3s
# [CV] n_estimators=400, learning_rate=0.11220184543 ...................
# [CV]  n_estimators=400, learning_rate=0.11220184543, score=0.935498 -   2.1s
# [CV] n_estimators=400, learning_rate=0.11220184543 ...................
# [CV]  n_estimators=400, learning_rate=0.11220184543, score=0.948062 -   0.7s
# [CV] n_estimators=400, learning_rate=0.11220184543 ...................
# [CV]  n_estimators=400, learning_rate=0.11220184543, score=0.954001 -   0.8s
# [CV] n_estimators=800, learning_rate=0.11220184543 ...................
# [CV]  n_estimators=800, learning_rate=0.11220184543, score=0.900895 -   1.4s
# [CV] n_estimators=800, learning_rate=0.11220184543 ...................
# [CV]  n_estimators=800, learning_rate=0.11220184543, score=0.920992 -   1.7s
# [CV] n_estimators=800, learning_rate=0.11220184543 ...................
# [CV]  n_estimators=800, learning_rate=0.11220184543, score=0.932943 -   1.9s
# [CV] n_estimators=800, learning_rate=0.11220184543 ...................
# [CV]  n_estimators=800, learning_rate=0.11220184543, score=0.945086 -   1.5s
# [CV] n_estimators=800, learning_rate=0.11220184543 ...................
# [CV]  n_estimators=800, learning_rate=0.11220184543, score=0.952559 -   1.5s
# [CV] n_estimators=100, learning_rate=0.375837404288 ..................
# [CV]  n_estimators=100, learning_rate=0.375837404288, score=0.903237 -   0.2s
# [CV] n_estimators=100, learning_rate=0.375837404288 ..................
# [CV]  n_estimators=100, learning_rate=0.375837404288, score=0.923889 -   0.2s
# [CV] n_estimators=100, learning_rate=0.375837404288 ..................
# [CV]  n_estimators=100, learning_rate=0.375837404288, score=0.933108 -   0.4s
# [CV] n_estimators=100, learning_rate=0.375837404288 ..................
# [CV]  n_estimators=100, learning_rate=0.375837404288, score=0.942805 -   0.8s
# [CV] n_estimators=100, learning_rate=0.375837404288 ..................
# [CV]  n_estimators=100, learning_rate=0.375837404288, score=0.951524 -   2.4s
# [CV] n_estimators=200, learning_rate=0.375837404288 ..................
# [CV]  n_estimators=200, learning_rate=0.375837404288, score=0.905866 -   5.5s
# [CV] n_estimators=200, learning_rate=0.375837404288 ..................
# [CV]  n_estimators=200, learning_rate=0.375837404288, score=0.927326 -   8.2s
# [CV] n_estimators=200, learning_rate=0.375837404288 ..................
# [CV]  n_estimators=200, learning_rate=0.375837404288, score=0.932427 -   0.4s
# [CV] n_estimators=200, learning_rate=0.375837404288 ..................
# [CV]  n_estimators=200, learning_rate=0.375837404288, score=0.943622 -   0.4s
# [CV] n_estimators=200, learning_rate=0.375837404288 ..................
# [CV]  n_estimators=200, learning_rate=0.375837404288, score=0.947474 -   0.6s
# [CV] n_estimators=400, learning_rate=0.375837404288 ..................
# [CV]  n_estimators=400, learning_rate=0.375837404288, score=0.904732 -   0.8s
# [CV] n_estimators=400, learning_rate=0.375837404288 ..................
# [CV]  n_estimators=400, learning_rate=0.375837404288, score=0.921651 -   1.0s
# [CV] n_estimators=400, learning_rate=0.375837404288 ..................
# [CV]  n_estimators=400, learning_rate=0.375837404288, score=0.931337 -   0.7s
# [CV] n_estimators=400, learning_rate=0.375837404288 ..................
# [CV]  n_estimators=400, learning_rate=0.375837404288, score=0.940256 -   0.8s
# [CV] n_estimators=400, learning_rate=0.375837404288 ..................
# [CV]  n_estimators=400, learning_rate=0.375837404288, score=0.947977 -   0.7s
# [CV] n_estimators=800, learning_rate=0.375837404288 ..................
# [CV]  n_estimators=800, learning_rate=0.375837404288, score=0.902981 -   1.5s
# [CV] n_estimators=800, learning_rate=0.375837404288 ..................
# [CV]  n_estimators=800, learning_rate=0.375837404288, score=0.918653 -   2.7s
# [CV] n_estimators=800, learning_rate=0.375837404288 ..................
# [CV]  n_estimators=800, learning_rate=0.375837404288, score=0.931658 -   2.5s
# [CV] n_estimators=800, learning_rate=0.375837404288 ..................
# [CV]  n_estimators=800, learning_rate=0.375837404288, score=0.941298 -   1.5s
# [CV] n_estimators=800, learning_rate=0.375837404288 ..................
# [CV]  n_estimators=800, learning_rate=0.375837404288, score=0.942944 -   1.0s
# [CV] n_estimators=100, learning_rate=1.25892541179 ...................
# [CV]  n_estimators=100, learning_rate=1.25892541179, score=0.887960 -   0.8s
# [CV] n_estimators=100, learning_rate=1.25892541179 ...................
# [CV]  n_estimators=100, learning_rate=1.25892541179, score=0.905867 -   0.2s
# [CV] n_estimators=100, learning_rate=1.25892541179 ...................
# [CV]  n_estimators=100, learning_rate=1.25892541179, score=0.913335 -   0.7s
# [CV] n_estimators=100, learning_rate=1.25892541179 ...................
# [CV]  n_estimators=100, learning_rate=1.25892541179, score=0.925169 -   0.2s
# [CV] n_estimators=100, learning_rate=1.25892541179 ...................
# [CV]  n_estimators=100, learning_rate=1.25892541179, score=0.918402 -   0.2s
# [CV] n_estimators=200, learning_rate=1.25892541179 ...................
# [CV]  n_estimators=200, learning_rate=1.25892541179, score=0.885037 -   0.3s
# [CV] n_estimators=200, learning_rate=1.25892541179 ...................
# [CV]  n_estimators=200, learning_rate=1.25892541179, score=0.904589 -   0.3s
# [CV] n_estimators=200, learning_rate=1.25892541179 ...................
# [CV]  n_estimators=200, learning_rate=1.25892541179, score=0.911932 -   0.3s
# [CV] n_estimators=200, learning_rate=1.25892541179 ...................
# [CV]  n_estimators=200, learning_rate=1.25892541179, score=0.925404 -   0.3s
# [CV] n_estimators=200, learning_rate=1.25892541179 ...................
# [CV]  n_estimators=200, learning_rate=1.25892541179, score=0.918960 -   0.3s
# [CV] n_estimators=400, learning_rate=1.25892541179 ...................
# [CV]  n_estimators=400, learning_rate=1.25892541179, score=0.884869 -   0.4s
# [CV] n_estimators=400, learning_rate=1.25892541179 ...................
# [CV]  n_estimators=400, learning_rate=1.25892541179, score=0.903939 -   0.4s
# [CV] n_estimators=400, learning_rate=1.25892541179 ...................
# [CV]  n_estimators=400, learning_rate=1.25892541179, score=0.911943 -   0.4s
# [CV] n_estimators=400, learning_rate=1.25892541179 ...................
# [CV]  n_estimators=400, learning_rate=1.25892541179, score=0.925196 -   0.4s
# [CV] n_estimators=400, learning_rate=1.25892541179 ...................
# [CV]  n_estimators=400, learning_rate=1.25892541179, score=0.918774 -   0.4s
# [CV] n_estimators=800, learning_rate=1.25892541179 ...................
# [CV]  n_estimators=800, learning_rate=1.25892541179, score=0.884558 -   0.6s
# [CV] n_estimators=800, learning_rate=1.25892541179 ...................
# [CV]  n_estimators=800, learning_rate=1.25892541179, score=0.903331 -   0.7s
# [CV] n_estimators=800, learning_rate=1.25892541179 ...................
# [CV]  n_estimators=800, learning_rate=1.25892541179, score=0.911913 -   0.6s
# [CV] n_estimators=800, learning_rate=1.25892541179 ...................
# [CV]  n_estimators=800, learning_rate=1.25892541179, score=0.925244 -   0.6s
# [CV] n_estimators=800, learning_rate=1.25892541179 ...................
# [CV]  n_estimators=800, learning_rate=1.25892541179, score=0.917150 -   0.6s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:  1.6min finished

# %%
plot_grid_Scores(grid)

# %% [markdown]
# Scores seem to decrease if you get above 200 estimators, possibly indicating that this is very prone to overfitting rather quickly?

# %% [markdown]
# Ideal parameters seem to be n_estimators less than 200, max_depth from around 6-10, colsample_by tree greater than 0.5, min_child wieght around 3, and subsample of about 0.9,  and a learning rate of about 0.01. Before moving on , lets try again and vary learning_rate with mich smaller values, < 0.01, and see if that helps to improve the scores.

# %%
learning_rate = np.logspace(-4,-3,8)
param_grid = dict(learning_rate = learning_rate)
grid = GridSearchCV(estimator = model3, param_grid = param_grid, scoring='average_precision',iid=False,cv=5, verbose = 10)
grid.fit(df_X.iloc[:Nrows_train], df_Y[:Nrows_train]) #10% of total dataset

# get the names of the parameters
param_names = param_grid.keys()
param_vals = [[val for val in param_grid[param_name]] for param_name in param_names]

param_val_names = {param_name:["{0}".format(val) for val in param_grid[param_name]] for param_name in param_names}
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV] learning_rate=0.0001 ............................................
# [CV] ................... learning_rate=0.0001, score=0.769554 -   0.5s
# [CV] learning_rate=0.0001 ............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [CV] ................... learning_rate=0.0001, score=0.770087 -   0.3s
# [CV] learning_rate=0.0001 ............................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.8s remaining:    0.0s
# [CV] ................... learning_rate=0.0001, score=0.768212 -   0.3s
# [CV] learning_rate=0.0001 ............................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    1.1s remaining:    0.0s
# [CV] ................... learning_rate=0.0001, score=0.807127 -   0.3s
# [CV] learning_rate=0.0001 ............................................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    1.4s remaining:    0.0s
# [CV] ................... learning_rate=0.0001, score=0.812477 -   0.3s
# [CV] learning_rate=0.000138949549437 .................................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    1.7s remaining:    0.0s
# [CV] ........ learning_rate=0.000138949549437, score=0.771672 -   0.3s
# [CV] learning_rate=0.000138949549437 .................................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    2.0s remaining:    0.0s
# [CV] ........ learning_rate=0.000138949549437, score=0.770087 -   0.3s
# [CV] learning_rate=0.000138949549437 .................................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    2.3s remaining:    0.0s
# [CV] ........ learning_rate=0.000138949549437, score=0.768536 -   0.3s
# [CV] learning_rate=0.000138949549437 .................................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    2.5s remaining:    0.0s
# [CV] ........ learning_rate=0.000138949549437, score=0.807134 -   0.3s
# [CV] learning_rate=0.000138949549437 .................................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    2.8s remaining:    0.0s
# [CV] ........ learning_rate=0.000138949549437, score=0.812360 -   0.3s
# [CV] learning_rate=0.000193069772888 .................................
# [CV] ........ learning_rate=0.000193069772888, score=0.771257 -   0.5s
# [CV] learning_rate=0.000193069772888 .................................
# [CV] ........ learning_rate=0.000193069772888, score=0.770087 -   0.3s
# [CV] learning_rate=0.000193069772888 .................................
# [CV] ........ learning_rate=0.000193069772888, score=0.768423 -   0.7s
# [CV] learning_rate=0.000193069772888 .................................
# [CV] ........ learning_rate=0.000193069772888, score=0.806863 -   0.3s
# [CV] learning_rate=0.000193069772888 .................................
# [CV] ........ learning_rate=0.000193069772888, score=0.812718 -   0.3s
# [CV] learning_rate=0.000268269579528 .................................
# [CV] ........ learning_rate=0.000268269579528, score=0.772778 -   0.3s
# [CV] learning_rate=0.000268269579528 .................................
# [CV] ........ learning_rate=0.000268269579528, score=0.770087 -   0.3s
# [CV] learning_rate=0.000268269579528 .................................
# [CV] ........ learning_rate=0.000268269579528, score=0.768805 -   0.3s
# [CV] learning_rate=0.000268269579528 .................................
# [CV] ........ learning_rate=0.000268269579528, score=0.806840 -   0.3s
# [CV] learning_rate=0.000268269579528 .................................
# [CV] ........ learning_rate=0.000268269579528, score=0.813192 -   0.3s
# [CV] learning_rate=0.000372759372031 .................................
# [CV] ........ learning_rate=0.000372759372031, score=0.774031 -   0.3s
# [CV] learning_rate=0.000372759372031 .................................
# [CV] ........ learning_rate=0.000372759372031, score=0.779322 -   0.3s
# [CV] learning_rate=0.000372759372031 .................................
# [CV] ........ learning_rate=0.000372759372031, score=0.768355 -   0.3s
# [CV] learning_rate=0.000372759372031 .................................
# [CV] ........ learning_rate=0.000372759372031, score=0.842493 -   0.3s
# [CV] learning_rate=0.000372759372031 .................................
# [CV] ........ learning_rate=0.000372759372031, score=0.814282 -   0.3s
# [CV] learning_rate=0.000517947467923 .................................
# [CV] ........ learning_rate=0.000517947467923, score=0.775106 -   0.3s
# [CV] learning_rate=0.000517947467923 .................................
# [CV] ........ learning_rate=0.000517947467923, score=0.780858 -   0.3s
# [CV] learning_rate=0.000517947467923 .................................
# [CV] ........ learning_rate=0.000517947467923, score=0.795306 -   0.3s
# [CV] learning_rate=0.000517947467923 .................................
# [CV] ........ learning_rate=0.000517947467923, score=0.843292 -   0.3s
# [CV] learning_rate=0.000517947467923 .................................
# [CV] ........ learning_rate=0.000517947467923, score=0.814257 -   0.3s
# [CV] learning_rate=0.000719685673001 .................................
# [CV] ........ learning_rate=0.000719685673001, score=0.777995 -   0.3s
# [CV] learning_rate=0.000719685673001 .................................
# [CV] ........ learning_rate=0.000719685673001, score=0.780858 -   0.3s
# [CV] learning_rate=0.000719685673001 .................................
# [CV] ........ learning_rate=0.000719685673001, score=0.820113 -   0.3s
# [CV] learning_rate=0.000719685673001 .................................
# [CV] ........ learning_rate=0.000719685673001, score=0.843340 -   0.3s
# [CV] learning_rate=0.000719685673001 .................................
# [CV] ........ learning_rate=0.000719685673001, score=0.816822 -   0.3s
# [CV] learning_rate=0.001 .............................................
# [CV] .................... learning_rate=0.001, score=0.778692 -   0.3s
# [CV] learning_rate=0.001 .............................................
# [CV] .................... learning_rate=0.001, score=0.781309 -   0.3s
# [CV] learning_rate=0.001 .............................................
# [CV] .................... learning_rate=0.001, score=0.821448 -   0.3s
# [CV] learning_rate=0.001 .............................................
# [CV] .................... learning_rate=0.001, score=0.845717 -   0.3s
# [CV] learning_rate=0.001 .............................................
# [CV] .................... learning_rate=0.001, score=0.814574 -   0.3s
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:   12.1s finished

# %%
print  grid.best_params_, grid.best_score_
print type(grid.grid_scores_)
for i in range (8):
    print grid.grid_scores_[i], "\n"
    
#plot_grid_Scores(grid)
# Out:
# {'learning_rate': 0.001} 0.808348175116
# <type 'list'>
# mean: 0.78549, std: 0.01993, params: {'learning_rate': 0.0001}
#
# mean: 0.78596, std: 0.01952, params: {'learning_rate': 0.00013894954943731373}
#
# mean: 0.78587, std: 0.01964, params: {'learning_rate': 0.00019306977288832496}
#
# mean: 0.78634, std: 0.01948, params: {'learning_rate': 0.00026826957952797245}
#
# mean: 0.79570, std: 0.02836, params: {'learning_rate': 0.00037275937203149379}
#
# mean: 0.80176, std: 0.02478, params: {'learning_rate': 0.0005179474679231213}
#
# mean: 0.80783, std: 0.02494, params: {'learning_rate': 0.00071968567300115217}
#
# mean: 0.80835, std: 0.02537, params: {'learning_rate': 0.001}

# %% [markdown]
# From above, it seems that the ideal value for learning rate is 0.001.

# %% [markdown]
# Now I will try running the optimal parameters found on the smaller datset with the full dataset, and then try to run a much finer grid search around those parameters

# %%
model4 = XGBClassifier(seed = 1, n_estimators=200, learning_rate=0.01, colsample_bytree= 0.8, max_depth = 8, min_child_weight =3, subsample= 0.9)
print df_X.shape, df_Y.shape
# Out:
# (14999, 28) (14999,)

# %%
score= cross_val_score(estimator= model4, cv = 5, scoring='average_precision', X=df_X, y=df_Y, verbose = 10)
print score
# Out:
# [CV]  ................................................................
# [CV] ................................. , score=0.943106, total=   1.8s
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s remaining:    0.0s
# [CV] ................................. , score=0.951132, total=   1.7s
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.6s remaining:    0.0s
# [CV] ................................. , score=0.947992, total=   1.8s
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.4s remaining:    0.0s
# [CV] ................................. , score=0.954688, total=   5.6s
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   11.0s remaining:    0.0s
# [CV] ................................. , score=0.950865, total=   1.7s
# [ 0.94310647  0.95113152  0.94799205  0.95468781  0.95086455]
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   12.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   12.7s finished

# %%
print np.mean(score), np.std(score)
# Out:
# 0.949556479683 0.00386192884588

# %%
model3 = XGBClassifier(seed = 3, learning_rate = 0.01, subsample = 0.9)
n_estimators = [175,200,225]
max_depth = [6,7,8,9]
cols_by_tree = np.linspace(0.7,0.9, 5)
min_c_w = np.linspace(3,8,6)
param_grid = dict(n_estimators = n_estimators, max_depth = max_depth, min_child_weight = min_c_w, colsample_bytree=cols_by_tree)
grid = GridSearchCV(estimator = model3, param_grid = param_grid, scoring='average_precision',iid=False,cv=5, verbose = 85)
grid.fit(df_X, df_Y) #total dataset

# get the names of the parameters
param_names = param_grid.keys()
param_vals = [[val for val in param_grid[param_name]] for param_name in param_names]
param_val_names = {param_name:["{0}".format(val) for val in param_grid[param_name]] for param_name in param_names}
# Out:
# Fitting 5 folds for each of 360 candidates, totalling 1800 fits
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0, score=0.935959 -   1.7s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0, score=0.943505 -   1.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.8s remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0, score=0.940830 -   1.1s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    3.9s remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0, score=0.947704 -   1.1s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    4.9s remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0, score=0.943442 -   1.1s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    6.0s remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0, score=0.937223 -   1.2s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    7.2s remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0, score=0.945334 -   1.2s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    8.4s remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0, score=0.942409 -   1.2s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    9.6s remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0, score=0.949094 -   1.2s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   10.9s remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0, score=0.944861 -   1.2s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:   12.1s remaining:    0.0s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0, score=0.938320 -   1.3s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:   13.5s remaining:    0.0s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0, score=0.946573 -   1.3s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:   14.8s remaining:    0.0s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0, score=0.943716 -   1.4s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:   16.2s remaining:    0.0s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0, score=0.950048 -   1.4s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:   17.6s remaining:    0.0s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=3.0, score=0.945975 -   1.4s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:   18.9s remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0, score=0.935755 -   1.1s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:   20.0s remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0, score=0.943711 -   1.1s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:   21.1s remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0, score=0.940828 -   1.1s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:   22.2s remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0, score=0.947732 -   1.1s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:   23.3s remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0, score=0.943429 -   1.1s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:   24.4s remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0, score=0.937015 -   1.2s
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:   25.6s remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0, score=0.945649 -   1.2s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:   26.9s remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0, score=0.942609 -   1.2s
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:   28.1s remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0, score=0.949130 -   1.2s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:   29.3s remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0, score=0.944789 -   1.2s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:   30.5s remaining:    0.0s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0, score=0.938231 -   4.3s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:   34.8s remaining:    0.0s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0, score=0.946855 -   1.3s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:   36.2s remaining:    0.0s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0, score=0.943942 -   1.3s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:   37.5s remaining:    0.0s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0, score=0.950131 -   1.4s
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:   38.9s remaining:    0.0s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=4.0, score=0.946115 -   1.3s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:   40.2s remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0, score=0.935879 -   1.1s
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed:   41.3s remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0, score=0.943943 -   1.1s
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed:   42.4s remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0, score=0.940959 -   1.1s
# [Parallel(n_jobs=1)]: Done  33 out of  33 | elapsed:   43.5s remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0, score=0.947500 -   1.1s
# [Parallel(n_jobs=1)]: Done  34 out of  34 | elapsed:   44.5s remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0, score=0.943601 -   1.1s
# [Parallel(n_jobs=1)]: Done  35 out of  35 | elapsed:   45.6s remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0, score=0.937076 -   1.2s
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed:   46.8s remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0, score=0.945961 -   1.3s
# [Parallel(n_jobs=1)]: Done  37 out of  37 | elapsed:   48.1s remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0, score=0.942635 -   1.2s
# [Parallel(n_jobs=1)]: Done  38 out of  38 | elapsed:   49.3s remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0, score=0.948948 -   1.2s
# [Parallel(n_jobs=1)]: Done  39 out of  39 | elapsed:   50.5s remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0, score=0.945184 -   1.4s
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:   51.9s remaining:    0.0s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0, score=0.938311 -   1.4s
# [Parallel(n_jobs=1)]: Done  41 out of  41 | elapsed:   53.2s remaining:    0.0s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0, score=0.947030 -   1.4s
# [Parallel(n_jobs=1)]: Done  42 out of  42 | elapsed:   54.6s remaining:    0.0s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0, score=0.943893 -   1.3s
# [Parallel(n_jobs=1)]: Done  43 out of  43 | elapsed:   55.9s remaining:    0.0s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0, score=0.950032 -   1.3s
# [Parallel(n_jobs=1)]: Done  44 out of  44 | elapsed:   57.2s remaining:    0.0s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=5.0, score=0.946495 -   1.3s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:   58.6s remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0, score=0.936010 -   1.0s
# [Parallel(n_jobs=1)]: Done  46 out of  46 | elapsed:   59.6s remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0, score=0.943761 -   1.1s
# [Parallel(n_jobs=1)]: Done  47 out of  47 | elapsed:  1.0min remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0, score=0.941068 -   1.0s
# [Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed:  1.0min remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0, score=0.947630 -   1.1s
# [Parallel(n_jobs=1)]: Done  49 out of  49 | elapsed:  1.0min remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0, score=0.943560 -   1.0s
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:  1.1min remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0, score=0.937209 -   1.2s
# [Parallel(n_jobs=1)]: Done  51 out of  51 | elapsed:  1.1min remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0, score=0.945817 -   1.2s
# [Parallel(n_jobs=1)]: Done  52 out of  52 | elapsed:  1.1min remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0, score=0.942666 -   1.2s
# [Parallel(n_jobs=1)]: Done  53 out of  53 | elapsed:  1.1min remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0, score=0.948944 -   1.2s
# [Parallel(n_jobs=1)]: Done  54 out of  54 | elapsed:  1.1min remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0, score=0.944974 -   1.2s
# [Parallel(n_jobs=1)]: Done  55 out of  55 | elapsed:  1.2min remaining:    0.0s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0, score=0.938500 -   1.4s
# [Parallel(n_jobs=1)]: Done  56 out of  56 | elapsed:  1.2min remaining:    0.0s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0, score=0.946945 -   1.4s
# [Parallel(n_jobs=1)]: Done  57 out of  57 | elapsed:  1.2min remaining:    0.0s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0, score=0.944160 -   1.3s
# [Parallel(n_jobs=1)]: Done  58 out of  58 | elapsed:  1.2min remaining:    0.0s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0, score=0.949955 -   1.3s
# [Parallel(n_jobs=1)]: Done  59 out of  59 | elapsed:  1.3min remaining:    0.0s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=6.0, score=0.946239 -   1.3s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:  1.3min remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0, score=0.935839 -   1.6s
# [Parallel(n_jobs=1)]: Done  61 out of  61 | elapsed:  1.3min remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0, score=0.943829 -   4.9s
# [Parallel(n_jobs=1)]: Done  62 out of  62 | elapsed:  1.4min remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0, score=0.941092 -   2.0s
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:  1.4min remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0, score=0.947481 -   1.1s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:  1.4min remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0, score=0.943525 -   1.0s
# [Parallel(n_jobs=1)]: Done  65 out of  65 | elapsed:  1.5min remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0, score=0.937107 -   1.2s
# [Parallel(n_jobs=1)]: Done  66 out of  66 | elapsed:  1.5min remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0, score=0.945839 -   1.2s
# [Parallel(n_jobs=1)]: Done  67 out of  67 | elapsed:  1.5min remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0, score=0.942852 -   1.3s
# [Parallel(n_jobs=1)]: Done  68 out of  68 | elapsed:  1.5min remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0, score=0.948882 -   1.3s
# [Parallel(n_jobs=1)]: Done  69 out of  69 | elapsed:  1.5min remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0, score=0.944930 -   1.2s
# [Parallel(n_jobs=1)]: Done  70 out of  70 | elapsed:  1.6min remaining:    0.0s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0, score=0.938334 -   1.3s
# [Parallel(n_jobs=1)]: Done  71 out of  71 | elapsed:  1.6min remaining:    0.0s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0, score=0.947029 -   1.3s
# [Parallel(n_jobs=1)]: Done  72 out of  72 | elapsed:  1.6min remaining:    0.0s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0, score=0.944220 -   1.3s
# [Parallel(n_jobs=1)]: Done  73 out of  73 | elapsed:  1.6min remaining:    0.0s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0, score=0.949931 -   1.4s
# [Parallel(n_jobs=1)]: Done  74 out of  74 | elapsed:  1.6min remaining:    0.0s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=7.0, score=0.946413 -   1.4s
# [Parallel(n_jobs=1)]: Done  75 out of  75 | elapsed:  1.7min remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0, score=0.936159 -   1.1s
# [Parallel(n_jobs=1)]: Done  76 out of  76 | elapsed:  1.7min remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0, score=0.943819 -   1.1s
# [Parallel(n_jobs=1)]: Done  77 out of  77 | elapsed:  1.7min remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0, score=0.941088 -   1.0s
# [Parallel(n_jobs=1)]: Done  78 out of  78 | elapsed:  1.7min remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0, score=0.947218 -   1.0s
# [Parallel(n_jobs=1)]: Done  79 out of  79 | elapsed:  1.7min remaining:    0.0s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0, score=0.943590 -   1.0s
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed:  1.8min remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0, score=0.937294 -   2.4s
# [Parallel(n_jobs=1)]: Done  81 out of  81 | elapsed:  1.8min remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0, score=0.945915 -   2.0s
# [Parallel(n_jobs=1)]: Done  82 out of  82 | elapsed:  1.8min remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0, score=0.942694 -   2.6s
# [Parallel(n_jobs=1)]: Done  83 out of  83 | elapsed:  1.9min remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0, score=0.948541 -   4.3s
# [Parallel(n_jobs=1)]: Done  84 out of  84 | elapsed:  1.9min remaining:    0.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0, score=0.944913 -   1.2s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0, score=0.938456 -   1.4s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0, score=0.946952 -   1.4s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0, score=0.943920 -   1.7s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0, score=0.949613 -   1.4s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=6, min_child_weight=8.0, score=0.946324 -   1.3s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0, score=0.940347 -   1.3s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0, score=0.948499 -   1.2s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0, score=0.944834 -   1.3s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0, score=0.951905 -  20.8s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0, score=0.946238 -   1.3s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0, score=0.941550 -   2.9s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0, score=0.950268 -   1.5s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0, score=0.946225 -  14.2s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0, score=0.953085 -  23.6s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0, score=0.947646 -   1.5s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0, score=0.942404 -   1.6s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0, score=0.951100 -   1.7s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0, score=0.947099 -   1.6s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0, score=0.953960 -   6.2s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=3.0, score=0.949091 -   1.7s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0, score=0.940368 -   1.3s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0, score=0.948726 -   1.3s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0, score=0.944996 -   1.3s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0, score=0.951856 -   1.3s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0, score=0.946529 -   1.2s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0, score=0.941424 -   1.4s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0, score=0.950467 -   1.5s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0, score=0.946507 -   1.5s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0, score=0.953002 -   6.1s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0, score=0.947985 -   1.5s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0, score=0.942401 -   1.6s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0, score=0.951469 -   1.6s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0, score=0.947668 -   1.6s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0, score=0.953724 -   1.6s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=4.0, score=0.949361 -   1.6s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0, score=0.940335 -   1.2s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0, score=0.948911 -   1.2s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0, score=0.944539 -   1.3s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0, score=0.951993 -   1.2s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0, score=0.946757 -   1.2s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0, score=0.941524 -   1.4s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0, score=0.950668 -   1.4s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0, score=0.945944 -   1.4s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0, score=0.953153 -   1.4s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0, score=0.948207 -   1.4s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0, score=0.942571 -   1.6s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0, score=0.951560 -   1.6s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0, score=0.947241 -   1.6s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0, score=0.953861 -   1.5s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=5.0, score=0.949400 -   1.6s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0, score=0.940113 -   1.2s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0, score=0.948646 -   1.3s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0, score=0.944694 -   1.2s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0, score=0.952007 -   1.2s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0, score=0.946704 -   1.2s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0, score=0.941222 -   1.5s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0, score=0.950447 -   1.5s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0, score=0.946170 -   1.5s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0, score=0.953146 -   1.4s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0, score=0.948160 -   1.4s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0, score=0.942335 -   1.6s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0, score=0.951417 -   3.2s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0, score=0.947366 -   1.7s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0, score=0.953847 -   1.6s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=6.0, score=0.949565 -   1.6s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0, score=0.939922 -   1.2s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0, score=0.948763 -   1.2s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0, score=0.944651 -   1.2s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0, score=0.951984 -   1.2s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0, score=0.946925 -   1.2s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0, score=0.941161 -   1.4s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0, score=0.950560 -   1.4s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0, score=0.946056 -   1.4s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0, score=0.953128 -   1.4s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0, score=0.948342 -   1.5s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0, score=0.942190 -   1.5s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0, score=0.951553 -   1.5s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0, score=0.947413 -   1.7s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0, score=0.953763 -   1.5s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=7.0, score=0.949571 -   1.5s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0, score=0.939938 -   1.2s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0, score=0.948554 -   1.2s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0, score=0.944842 -   1.2s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0, score=0.951721 -   1.2s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0, score=0.946744 -   1.2s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0, score=0.941022 -   1.4s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0, score=0.950421 -   1.4s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0, score=0.946304 -   1.3s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0, score=0.952906 -   1.4s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0, score=0.948147 -   1.4s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0, score=0.941974 -   1.5s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0, score=0.951429 -   1.5s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0, score=0.947641 -   1.6s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0, score=0.953487 -   1.5s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=7, min_child_weight=8.0, score=0.949386 -   1.6s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0, score=0.942401 -   4.4s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0, score=0.952162 -   1.5s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0, score=0.948124 -   1.5s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0, score=0.954766 -   1.5s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0, score=0.948966 -   1.5s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0, score=0.943271 -   1.7s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0, score=0.953252 -   1.7s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0, score=0.949435 -   1.6s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0, score=0.955542 -   1.6s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0, score=0.950311 -   1.7s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0, score=0.944360 -   1.9s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0, score=0.954011 -   1.9s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0, score=0.950366 -   1.9s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0, score=0.956144 -   1.8s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=8, min_child_weight=3.0, score=0.951617 -  21.2s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0, score=0.943217 -   1.5s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0, score=0.952165 -   1.5s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0, score=0.948488 -   1.4s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0, score=0.954396 -   1.4s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0, score=0.948974 -   1.4s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0, score=0.943915 -   1.7s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0, score=0.953291 -   1.7s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0, score=0.949711 -   1.7s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0, score=0.955197 -   7.6s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0, score=0.950462 -  38.5s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0, score=0.944875 -   1.8s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0, score=0.954025 -   1.8s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0, score=0.950631 -   1.9s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0, score=0.956008 -   1.8s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=8, min_child_weight=4.0, score=0.951548 -   1.9s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=5.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=5.0, score=0.942914 -   1.5s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=5.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=5.0, score=0.951711 -   1.4s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=5.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=5.0, score=0.948132 -   1.4s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=5.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=5.0, score=0.954731 -   1.5s
# [CV] n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=5.0
# [CV]  n_estimators=175, colsample_bytree=0.7, max_depth=8, min_child_weight=5.0, score=0.949344 -   1.4s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=5.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=5.0, score=0.943659 -   4.7s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=5.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=5.0, score=0.953056 -   1.6s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=5.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=5.0, score=0.949248 -  44.0s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=5.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=5.0, score=0.955476 -   1.6s
# [CV] n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=5.0
# [CV]  n_estimators=200, colsample_bytree=0.7, max_depth=8, min_child_weight=5.0, score=0.950780 -   1.8s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=8, min_child_weight=5.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=8, min_child_weight=5.0, score=0.944674 -   1.8s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=8, min_child_weight=5.0
# [CV]  n_estimators=225, colsample_bytree=0.7, max_depth=8, min_child_weight=5.0, score=0.953807 -   1.8s
# [CV] n_estimators=225, colsample_bytree=0.7, max_depth=8, min_child_weight=5.0
# ...
# [CV] n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=3.0
# [CV]  n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=3.0, score=0.952192 -   1.7s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=3.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=3.0, score=0.944646 -   1.9s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=3.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=3.0, score=0.953395 -   1.9s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=3.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=3.0, score=0.947917 -   2.0s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=3.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=3.0, score=0.955177 -   2.0s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=3.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=3.0, score=0.953244 -   2.0s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=3.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=3.0, score=0.946384 -   2.1s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=3.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=3.0, score=0.954274 -   2.2s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=3.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=3.0, score=0.948720 -   2.2s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=3.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=3.0, score=0.955520 -   2.2s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=3.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=3.0, score=0.954275 -   2.2s
# [CV] n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0
# [CV]  n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0, score=0.944175 -   1.7s
# [CV] n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0
# [CV]  n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0, score=0.952124 -   1.7s
# [CV] n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0
# [CV]  n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0, score=0.946344 -   1.7s
# [CV] n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0
# [CV]  n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0, score=0.953794 -   1.7s
# [CV] n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0
# [CV]  n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0, score=0.951939 -   1.7s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0, score=0.945293 -   1.9s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0, score=0.953060 -   1.9s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0, score=0.947605 -   1.9s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0, score=0.954589 -   1.9s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0, score=0.952850 -   2.0s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0, score=0.946763 -   2.1s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0, score=0.954046 -   2.1s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0, score=0.948575 -   2.1s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0, score=0.955010 -   2.1s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=4.0, score=0.954133 -   2.1s
# [CV] n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0
# [CV]  n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0, score=0.943927 -   1.6s
# [CV] n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0
# [CV]  n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0, score=0.952203 -   1.6s
# [CV] n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0
# [CV]  n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0, score=0.946438 -   1.6s
# [CV] n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0
# [CV]  n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0, score=0.953785 -   5.2s
# [CV] n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0
# [CV]  n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0, score=0.952030 -   1.6s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0, score=0.944984 -   1.8s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0, score=0.953407 -   1.9s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0, score=0.947875 -   1.9s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0, score=0.954751 -   2.2s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0, score=0.953021 -   1.9s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0, score=0.946505 -   2.1s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0, score=0.954221 -   2.1s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0, score=0.948969 -   2.1s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0, score=0.955346 -   2.1s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=5.0, score=0.954104 -   3.0s
# [CV] n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0
# [CV]  n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0, score=0.943833 -   1.6s
# [CV] n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0
# [CV]  n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0, score=0.952018 -   1.6s
# [CV] n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0
# [CV]  n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0, score=0.946247 -   1.6s
# [CV] n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0
# [CV]  n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0, score=0.953891 -   1.6s
# [CV] n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0
# [CV]  n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0, score=0.951435 -   2.3s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0, score=0.945001 -   1.8s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0, score=0.953090 -   1.9s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0, score=0.947593 -   1.8s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0, score=0.954762 -   1.8s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0, score=0.952588 -   1.8s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0, score=0.946605 -   2.0s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0, score=0.954090 -   2.0s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0, score=0.948922 -   2.0s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0, score=0.955310 -   2.1s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=6.0, score=0.953777 -   2.1s
# [CV] n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0
# [CV]  n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0, score=0.943733 -   1.6s
# [CV] n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0
# [CV]  n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0, score=0.951858 -   1.5s
# [CV] n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0
# [CV]  n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0, score=0.946590 -   1.6s
# [CV] n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0
# [CV]  n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0, score=0.953371 -   1.6s
# [CV] n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0
# [CV]  n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0, score=0.951124 -   1.6s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0, score=0.944957 -   1.8s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0, score=0.952989 -   1.8s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0, score=0.947685 -   1.8s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0, score=0.954213 -   1.8s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0, score=0.952017 -   1.8s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0, score=0.946516 -   2.0s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0, score=0.953997 -   2.0s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0, score=0.948922 -   2.0s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0, score=0.954812 -   2.0s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=7.0, score=0.953251 -   2.0s
# [CV] n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0
# [CV]  n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0, score=0.944122 -   1.6s
# [CV] n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0
# [CV]  n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0, score=0.951468 -   1.6s
# [CV] n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0
# [CV]  n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0, score=0.946543 -   1.5s
# [CV] n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0
# [CV]  n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0, score=0.953081 -   1.5s
# [CV] n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0
# [CV]  n_estimators=175, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0, score=0.951221 -   1.5s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0, score=0.945436 -   1.7s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0, score=0.952503 -   4.0s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0, score=0.947891 -   1.8s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0, score=0.953918 -   1.7s
# [CV] n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0
# [CV]  n_estimators=200, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0, score=0.952371 -   1.8s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0, score=0.946732 -   2.0s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0, score=0.953644 -   2.2s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0, score=0.948984 -   2.3s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0, score=0.954475 -   1.9s
# [CV] n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0
# [CV]  n_estimators=225, colsample_bytree=0.9, max_depth=9, min_child_weight=8.0, score=0.953539 -   1.9s
# [Parallel(n_jobs=1)]: Done 1800 out of 1800 | elapsed: 53.8min finished

# %%
print grid.best_params_
print grid.best_score_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0b1027ddf272> in <module>()
# ----> 1 print grid.best_params_
#       2 print grid.best_score_
#
# NameError: name 'grid' is not defined

# %% [markdown]
# The results from above if rerun should show best score is ~0.95.3 % and that the best parameters are 225 n_estimators, 0.75 for colsample_by_tree, max_depth = 9, and min child_weight = 4

# %%
model3 = XGBClassifier(seed = 3, learning_rate = 0.01, subsample = 0.9, n_estimators=225, colsample_bytree=0.75, max_depth=9, min_child_weight=4)
from sklearn.model_selection import train_test_split

# %%
#x = df_X.as_matrix()
#y = df_Y.as_matrix()
#trainX, testX, trainY, testY = train_test_split(x, y, test_size = 0.3) 
N_rows = 0.4
size_data = int(N_rows*df_X.shape[0])
trainX = df_X.iloc[:size_data,:]
testX = df_X.iloc[size_data:,:]
trainY = df_Y.iloc[:size_data]
testY = df_Y.iloc[size_data:]
testX.head()
# Out:
#        RHill12   RHill23     beta12     beta23            m1   a1        P1  \
# 5999  0.015772  0.017028   6.773663   5.205774  1.117547e-06  1.0  0.999999
# 6000  0.006025  0.006869  22.444698   2.553982  3.325170e-07  1.0  1.000000
# 6001  0.028916  0.033257   6.025676  19.750872  5.581965e-05  1.0  0.999972
# 6002  0.018846  0.019744  18.780961   1.558363  1.984420e-05  1.0  0.999990
# 6003  0.033772  0.036555   8.836667  12.131602  5.752539e-05  1.0  0.999971
#
#             e1   pomega1      inc1    ...       Omega2        f2  \
# 5999  0.003523 -1.397882  0.013937    ...    -1.746653  2.470031
# 6000  0.119197 -1.646663  0.003442    ...    -1.909445  2.070047
# 6001  0.025069  2.708309  0.002314    ...    -2.229838 -1.425401
# 6002  0.011073  0.473887  0.069877    ...    -1.093548 -3.106225
# 6003  0.213781  5.006837  0.001318    ...    -0.389004 -0.555931
#
#                 m3        a3        P3        e3   pomega3      inc3  \
# 5999  2.699462e-07  1.195477  1.307101  0.006471 -2.985619  0.002335
# 6000  3.410894e-07  1.152763  1.237685  0.006913 -4.564619  0.007310
# 6001  5.144203e-05  1.831100  2.477656  0.293910 -3.786828  0.090252
# 6002  9.066704e-06  1.384715  1.629424  0.008385  1.299528  0.066571
# 6003  8.914196e-06  1.741895  2.298826  0.051872 -1.687367  0.005635
#
#         Omega3        f3
# 5999  0.003401  5.668057
# 6000 -1.528003  2.806849
# 6001 -1.538660  2.190290
# 6002 -0.208057 -2.224395
# 6003 -3.025624 -0.521704
#
# [5 rows x 28 columns]

# %%
model3.fit(trainX, trainY)
# Out:
# XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.75,
#        gamma=0, learning_rate=0.01, max_delta_step=0, max_depth=9,
#        min_child_weight=4, missing=None, n_estimators=225, nthread=-1,
#        objective='binary:logistic', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=3, silent=True, subsample=0.9)

# %%
preds = model3.predict(testX)
dtest_predprob = model3.predict_proba(testX)[:,1]
print preds, dtest_predprob
# Out:
# [0 0 0 ..., 1 1 0] [ 0.06339621  0.06243013  0.12584913 ...,  0.74622023  0.91557568
#   0.11988813]

# %%
from matplotlib import rc, cm

rc('text',usetex=True)
rc('font',family='serif')
rc('font',serif='cm')
rc('font',size=15,weight='black',stretch='extra-expanded',style='oblique')
rc('axes',linewidth=2)

#Print model report:
print "\nModel Report"
print "Accuracy : %.4g" % metrics.accuracy_score(testY, preds)
#print "AUC Score (Train): %f" % metrics.roc_auc_score(df['Stable'], dtrain_predprob)
print "AUC Score (Test): %f" % metrics.average_precision_score(testY, dtest_predprob)

fig = plt.figure(figsize = (12,7))
ax = fig.add_subplot(111)
ax.tick_params(axis='both', which='major', pad=3)


xgb.plot_importance(model3, ax = ax,  height = 0.3 )
# Out:
# Model Report
# Accuracy : 0.9584
# AUC Score (Test): 0.987750

# %%
# Histogram:

bins = 50
pred_prob= model3.predict_proba(testX)[:,1]
Stable=pred_prob[np.where(testY==1)]
print Stable[:5][:]
Unstable=pred_prob[np.where(testY==0)]
print Stable.size, Unstable.size

fig, ax1 = plt.subplots()
ax1.hist([Unstable, Stable], bins, alpha=0.5, label='No', color=['blue', 'green'], linewidth = 1, edgecolor='black', histtype='barstacked')
#ax1.hist(Stable, bins, alpha=0.5, label='Yes',color='green', linewidth = 1, edgecolor='black', histtype='barstacked')
print Stable.size
ax1.set_xlabel('Predicted Probability', fontsize=14)
ax1.set_ylabel('Unstable',  fontsize=14, color='blue')
for tl in ax1.get_yticklabels():
    tl.set_color('blue')
    

ax2 = ax1.twinx()
#ax2.hist(Stable, bins, alpha=0.5, label='Yes',color='green', linewidth = 1, edgecolor='black', histtype='barstacked')
ax2.set_ylabel('Stable', fontsize=14, color='green')
for tl in ax2.get_yticklabels():
    tl.set_color('green')
 
#ax1.set_ylim(ax2.get_ylim())
ax1.set_ylim([0,900])
ax2.set_ylim([0,900])
# Out:
# [ 0.89110845  0.74576855  0.88852847  0.87951738  0.82772458]
# 1731 2769
# 1731
# (0, 900)

# %%
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(testY, pred_prob)
fig, ax = plt.subplots()
ax.plot(fpr, tpr)
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.0])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC curve (AUC = {0:.3f})'.format(metrics.roc_auc_score(testY, dtest_predprob)))

# %%
for i in range(0,len(fpr), 10):
    print("Threshold {0}, FPR = {1}, TPR = {2}".format(thresholds[i], fpr[i], tpr[i]))
# Out:
# Threshold 0.92608833313, FPR = 0.0, TPR = 0.000566893424036
# Threshold 0.865586578846, FPR = 0.00182748538012, TPR = 0.33843537415
# Threshold 0.845925450325, FPR = 0.00365497076023, TPR = 0.413265306122
# Threshold 0.830231070518, FPR = 0.00548245614035, TPR = 0.456916099773
# Threshold 0.806395947933, FPR = 0.00730994152047, TPR = 0.518140589569
# Threshold 0.790718078613, FPR = 0.00913742690058, TPR = 0.5589569161
# Threshold 0.780887722969, FPR = 0.0109649122807, TPR = 0.569727891156
# Threshold 0.772174596786, FPR = 0.0131578947368, TPR = 0.582766439909
# Threshold 0.764717876911, FPR = 0.014985380117, TPR = 0.59410430839
# Threshold 0.752677202225, FPR = 0.0171783625731, TPR = 0.616780045351
# Threshold 0.731778740883, FPR = 0.0190058479532, TPR = 0.646258503401
# Threshold 0.72030621767, FPR = 0.0211988304094, TPR = 0.660430839002
# Threshold 0.705889225006, FPR = 0.0233918128655, TPR = 0.678571428571
# Threshold 0.699755191803, FPR = 0.0255847953216, TPR = 0.689909297052
# Threshold 0.691998064518, FPR = 0.0277777777778, TPR = 0.696712018141
# Threshold 0.680847287178, FPR = 0.0299707602339, TPR = 0.706916099773
# Threshold 0.671930015087, FPR = 0.0325292397661, TPR = 0.719387755102
# Threshold 0.662221968174, FPR = 0.0350877192982, TPR = 0.727891156463
# Threshold 0.645247638226, FPR = 0.0369152046784, TPR = 0.741496598639
# Threshold 0.632647752762, FPR = 0.0402046783626, TPR = 0.751133786848
# Threshold 0.616972208023, FPR = 0.0420321637427, TPR = 0.767006802721
# Threshold 0.610892832279, FPR = 0.0442251461988, TPR = 0.771541950113
# Threshold 0.595720529556, FPR = 0.046783625731, TPR = 0.781179138322
# Threshold 0.584582567215, FPR = 0.0489766081871, TPR = 0.789682539683
# Threshold 0.57873660326, FPR = 0.0511695906433, TPR = 0.795918367347
# Threshold 0.568980157375, FPR = 0.0529970760234, TPR = 0.801587301587
# Threshold 0.557627737522, FPR = 0.0559210526316, TPR = 0.8089569161
# Threshold 0.547486364841, FPR = 0.0599415204678, TPR = 0.815759637188
# Threshold 0.537021696568, FPR = 0.062134502924, TPR = 0.821995464853
# Threshold 0.529440701008, FPR = 0.0654239766082, TPR = 0.827664399093
# Threshold 0.517446279526, FPR = 0.0694444444444, TPR = 0.834467120181
# Threshold 0.510008752346, FPR = 0.0716374269006, TPR = 0.841836734694
# Threshold 0.499358773232, FPR = 0.0745614035088, TPR = 0.84977324263
# Threshold 0.491870433092, FPR = 0.077850877193, TPR = 0.854308390023
# Threshold 0.478417247534, FPR = 0.0829678362573, TPR = 0.861678004535
# Threshold 0.463720738888, FPR = 0.0877192982456, TPR = 0.870181405896
# Threshold 0.457125604153, FPR = 0.0913742690058, TPR = 0.874149659864
# Threshold 0.449482351542, FPR = 0.0946637426901, TPR = 0.881519274376
# Threshold 0.441614508629, FPR = 0.0972222222222, TPR = 0.888321995465
# Threshold 0.434337168932, FPR = 0.101608187135, TPR = 0.891723356009
# Threshold 0.425525039434, FPR = 0.106725146199, TPR = 0.896825396825
# Threshold 0.414312303066, FPR = 0.112938596491, TPR = 0.901927437642
# Threshold 0.403349101543, FPR = 0.118786549708, TPR = 0.90873015873
# Threshold 0.394236773252, FPR = 0.123903508772, TPR = 0.913832199546
# Threshold 0.387091398239, FPR = 0.128289473684, TPR = 0.917800453515
# Threshold 0.379074722528, FPR = 0.133040935673, TPR = 0.921768707483
# Threshold 0.370903402567, FPR = 0.137061403509, TPR = 0.925170068027
# Threshold 0.362570732832, FPR = 0.144736842105, TPR = 0.928004535147
# Threshold 0.35614964366, FPR = 0.148757309942, TPR = 0.931405895692
# Threshold 0.34855017066, FPR = 0.154605263158, TPR = 0.934240362812
# Threshold 0.338740885258, FPR = 0.16081871345, TPR = 0.937074829932
# Threshold 0.326966106892, FPR = 0.167032163743, TPR = 0.942743764172
# Threshold 0.318303912878, FPR = 0.175804093567, TPR = 0.946145124717
# Threshold 0.307256013155, FPR = 0.18384502924, TPR = 0.950113378685
# Threshold 0.288838535547, FPR = 0.199561403509, TPR = 0.952947845805
# Threshold 0.278415441513, FPR = 0.208333333333, TPR = 0.956349206349
# Threshold 0.267148703337, FPR = 0.219298245614, TPR = 0.959183673469
# Threshold 0.261295646429, FPR = 0.224780701754, TPR = 0.962585034014
# Threshold 0.249642699957, FPR = 0.239400584795, TPR = 0.965419501134
# Threshold 0.236304596066, FPR = 0.260233918129, TPR = 0.969387755102
# Threshold 0.218829080462, FPR = 0.281432748538, TPR = 0.972789115646
# Threshold 0.216019153595, FPR = 0.286549707602, TPR = 0.97619047619
# Threshold 0.193404346704, FPR = 0.327119883041, TPR = 0.979591836735
# Threshold 0.179014116526, FPR = 0.355628654971, TPR = 0.982426303855
# Threshold 0.168601453304, FPR = 0.379385964912, TPR = 0.985260770975
# Threshold 0.152552708983, FPR = 0.419590643275, TPR = 0.988095238095
# Threshold 0.142032772303, FPR = 0.442251461988, TPR = 0.990929705215
# Threshold 0.133321121335, FPR = 0.468932748538, TPR = 0.993764172336
# Threshold 0.109024882317, FPR = 0.529970760234, TPR = 0.99716553288
# Threshold 0.0551589131355, FPR = 0.985380116959, TPR = 1.0

# %%
from sklearn.metrics import precision_recall_curve
precision, recall, thresholds = precision_recall_curve(testY, dtest_predprob)
fig, ax = plt.subplots()
ax.plot(recall, precision)
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.0])
ax.set_xlabel('Recall')
ax.set_ylabel('Precision')
ax.set_title('Precision Recall curve')
print "AUC Score (Test): %f" % metrics.average_precision_score(testY, dtest_predprob)
# Out:
# AUC Score (Test): 0.987750
