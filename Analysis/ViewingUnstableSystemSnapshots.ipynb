# %%
import pandas as pd
import numpy as np
import time
import os
import rebound
import matplotlib 
from collections import OrderedDict
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
def orbital_times(sys_name):
    time_path = "../../LongScalesCsvs2/Sys_{0}_1e8.csv".format(sys_name)
    times = pd.read_csv(time_path)
    times = times.sort_values("t", ascending=False)
    print times.head()

def orbital_evolution(sys_name, snapshot, lim = None):
    #sys name is an int, snapshot is an string, three sharacters
    path = '../../Corrupted/Sys_'+str(sys_name)+'_1e8/simulation_archives/' # your path here
    index = snapshot #enter 3 digit number here
    sa = rebound.SimulationArchive(path+'sa0000'+index+'.bin') 
    views = len(sa)
    #print times.loc[int(index)]["t"]

    for i in range(views):
        sim = sa[i]
        fig = rebound.OrbitPlot(sim, color = True, slices=True, lim = lim)

# %% [markdown]
# Two inner planets are too close, too short to have more than one snap shot, IGNORE

# %%
print os.listdir("../../Corrupted/.")
sys_name = 4641
orbital_times(sys_name=sys_name)
orbital_evolution(sys_name=sys_name, snapshot="388")
# Out:
# ['Sys_4641_1e8', 'Sys_8582_1e8', 'Sys_13662_1e8', 'Sys_24013_1e8', 'Sys_2059_1e8', 'Sys_1424_1e8', 'Sys_22032_1e8', 'Sys_1886_1e8', 'Sys_7341_1e8', 'Sys_2105_1e8', 'Sys_1364_1e8', 'Sys_1508_1e8']
#      Unnamed: 0  Unnamed: 0.1    runstring            t
# 388         388           388  0000388.bin  5705.637796
# 102         102           102  0000102.bin  1981.634226
# 69           69            69  0000069.bin   898.758850
# 807         807           807  0000807.bin   895.641166
# 991         991           991  0000991.bin   620.037951
# /home/naireen/anaconda2/lib/python2.7/site-packages/rebound/simulationarchive.py:63: RuntimeWarning: Binary file was saved with a different version of REBOUND. Binary format might have changed.
#   warnings.warn(BINARY_WARNINGS[1][0], RuntimeWarning)

# %% [markdown]
# Too short for more than one snap shot IGNORE

# %%
print os.listdir("../../Corrupted/.")
sys_name = 8582
orbital_times(sys_name=sys_name)
orbital_evolution(sys_name=sys_name, snapshot="099")
# Out:
# ['Sys_4641_1e8', 'Sys_8582_1e8', 'Sys_13662_1e8', 'Sys_24013_1e8', 'Sys_2059_1e8', 'Sys_1424_1e8', 'Sys_22032_1e8', 'Sys_1886_1e8', 'Sys_7341_1e8', 'Sys_2105_1e8', 'Sys_1364_1e8', 'Sys_1508_1e8']
#      Unnamed: 0  Unnamed: 0.1    runstring          t
# 406         406           406  0000406.bin  99.177176
# 869         869           869  0000869.bin  99.177176
# 868         868           868  0000868.bin  99.177176
# 532         532           532  0000532.bin  99.177176
# 533         533           533  0000533.bin  99.177176

# %% [markdown]
# In the longest simulation, the outer planet very quickly develops a very ecentric and large orbit (ejected?), Delete lim parameter to see, and then in the rest, it is retained (possibly?), and becomes instable far quicker. Does that mean that in the other simulations, it terminated becasue the middle and outer planet become too close? Becuase its clear that run 137 terminated because of the inner two planets

# %%
#need to look into this system, is it 13662 or 13362?
print os.listdir("../../Corrupted/.")
sys_name = 13662
orbital_times(sys_name=sys_name)       
#looks like this planet was ejected from the system
orbital_evolution(sys_name=sys_name, snapshot="137", lim=10)
# Out:
# ['Sys_4641_1e8', 'Sys_8582_1e8', 'Sys_13662_1e8', 'Sys_24013_1e8', 'Sys_2059_1e8', 'Sys_1424_1e8', 'Sys_22032_1e8', 'Sys_1886_1e8', 'Sys_7341_1e8', 'Sys_2105_1e8', 'Sys_1364_1e8', 'Sys_1508_1e8']
#      Unnamed: 0  Unnamed: 0.1    runstring             t
# 137         137           137  0000137.bin  1.401759e+06
# 373         373           373  0000373.bin  2.440533e+04
# 428         428           428  0000428.bin  2.170341e+04
# 745         745           745  0000745.bin  1.438632e+04
# 849         849           849  0000849.bin  1.008569e+04

# %% [markdown]
# TOo short for more than one snap shot, system can be ignored.

# %%
print os.listdir("../../Corrupted/.")
sys_name = 24013
orbital_times(sys_name=sys_name)
orbital_evolution(sys_name=sys_name, snapshot="388")
# Out:
# ['Sys_4641_1e8', 'Sys_8582_1e8', 'Sys_13662_1e8', 'Sys_24013_1e8', 'Sys_2059_1e8', 'Sys_1424_1e8', 'Sys_22032_1e8', 'Sys_1886_1e8', 'Sys_2105_1e8', 'Sys_1364_1e8', 'Sys_1508_1e8']
#      Unnamed: 0  Unnamed: 0.1    runstring            t
# 559         559           559  0000559.bin  3035.298581
# 651         651           651  0000651.bin  1856.298019
# 139         139           139  0000139.bin  1668.440812
# 266         266           266  0000266.bin  1625.797954
# 288         288           288  0000288.bin  1270.417705

# %% [markdown]
# Interesting system, has a signifcantly longer stability timescale, yet exponential distribtion. Seems like over its lifetime, the planet's plane of orbit changed by 90 degrees?

# %%
print os.listdir("../../Corrupted/.")
sys_name = 2059
orbital_times(sys_name=sys_name)
orbital_evolution(sys_name=sys_name, snapshot="530")
# Out:
# ['Sys_4641_1e8', 'Sys_8582_1e8', 'Sys_13662_1e8', 'Sys_24013_1e8', 'Sys_2059_1e8', 'Sys_1424_1e8', 'Sys_22032_1e8', 'Sys_1886_1e8', 'Sys_2105_1e8', 'Sys_1364_1e8', 'Sys_1508_1e8']
#      Unnamed: 0  Unnamed: 0.1    runstring             t
# 530         530           530  0000530.bin  1.843830e+06
# 243         243           243  0000243.bin  1.775895e+06
# 563         563           563  0000563.bin  1.313047e+06
# 199         199           199  0000199.bin  1.297665e+06
# 794         794           794  0000794.bin  9.773710e+05

# %% [markdown]
# Too short for another snap shot, cant be ignored

# %%
print os.listdir("../../Corrupted/.")
sys_name = 1424
orbital_times(sys_name=sys_name)
orbital_evolution(sys_name=sys_name, snapshot="392")
# Out:
# ['Sys_4641_1e8', 'Sys_8582_1e8', 'Sys_13662_1e8', 'Sys_24013_1e8', 'Sys_2059_1e8', 'Sys_1424_1e8', 'Sys_22032_1e8', 'Sys_1886_1e8', 'Sys_2105_1e8', 'Sys_1364_1e8', 'Sys_1508_1e8']
#      Unnamed: 0  Unnamed: 0.1    runstring             t
# 392         392           392  0000392.bin  52370.388520
# 327         327           327  0000327.bin  36602.387955
# 385         385           385  0000385.bin  36450.729596
# 77           77            77  0000077.bin  31573.551987
# 137         137           137  0000137.bin  26799.500676

# %% [markdown]
# Too short for more than one snap shot, IGNORED

# %%
print os.listdir("../../Corrupted/.")
sys_name = 22032
orbital_times(sys_name=sys_name)
orbital_evolution(sys_name=sys_name, snapshot="392")
# Out:
# ['Sys_4641_1e8', 'Sys_8582_1e8', 'Sys_13662_1e8', 'Sys_24013_1e8', 'Sys_2059_1e8', 'Sys_1424_1e8', 'Sys_22032_1e8', 'Sys_1886_1e8', 'Sys_2105_1e8', 'Sys_1364_1e8', 'Sys_1508_1e8']
#      Unnamed: 0  Unnamed: 0.1    runstring           t
# 921         921           921  0000921.bin  274.283004
# 942         942           942  0000942.bin  248.960842
# 762         762           762  0000762.bin  232.021667
# 435         435           435  0000435.bin  228.245859
# 520         520           520  0000520.bin  218.304053

# %% [markdown]
# Too short for another snapshot, CANT be ignored

# %%
print os.listdir("../../Corrupted/.")
sys_name = 1886
orbital_times(sys_name=sys_name)
orbital_evolution(sys_name=sys_name, snapshot="881")
# Out:
# ['Sys_4641_1e8', 'Sys_8582_1e8', 'Sys_13662_1e8', 'Sys_24013_1e8', 'Sys_2059_1e8', 'Sys_1424_1e8', 'Sys_22032_1e8', 'Sys_1886_1e8', 'Sys_2105_1e8', 'Sys_1364_1e8', 'Sys_1508_1e8']
#      Unnamed: 0  Unnamed: 0.1    runstring             t
# 881         881           881  0000881.bin  62475.622934
# 131         131           131  0000131.bin  61867.465293
# 266         266           266  0000266.bin  61624.389298
# 395         395           395  0000395.bin  61614.412686
# 227         227           227  0000227.bin  61547.451606

# %% [markdown]
# Too short for another snap shot, IGNORED

# %%
print os.listdir("../../Corrupted/.")
sys_name = 7341
orbital_times(sys_name=sys_name)
orbital_evolution(sys_name=sys_name, snapshot="537")
# Out:
# ['Sys_4641_1e8', 'Sys_8582_1e8', 'Sys_13662_1e8', 'Sys_24013_1e8', 'Sys_2059_1e8', 'Sys_1424_1e8', 'Sys_22032_1e8', 'Sys_1886_1e8', 'Sys_7341_1e8', 'Sys_2105_1e8', 'Sys_1364_1e8', 'Sys_1508_1e8']
#      Unnamed: 0  Unnamed: 0.1    runstring            t
# 537         537           537  0000537.bin  9106.423166
# 980         980           980  0000980.bin  6437.750662
# 421         421           421  0000421.bin  5908.644197
# 509         509           509  0000509.bin  3327.890523
# 511         511           511  0000511.bin  3197.293995

# %% [markdown]
# Run 864 surprisingly is stable past the cut off? and then the rest (other than run 969) are to short to have more than 1 snap shot

# %%
print os.listdir("../../Corrupted/.")
sys_name = 2105
orbital_times(sys_name=sys_name)
orbital_evolution(sys_name=sys_name, snapshot="969")
# Out:
# ['Sys_4641_1e8', 'Sys_8582_1e8', 'Sys_13662_1e8', 'Sys_24013_1e8', 'Sys_2059_1e8', 'Sys_1424_1e8', 'Sys_22032_1e8', 'Sys_1886_1e8', 'Sys_2105_1e8', 'Sys_1364_1e8', 'Sys_1508_1e8']
#      Unnamed: 0  Unnamed: 0.1    runstring             t
# 864         864           864  0000864.bin  1.000000e+08
# 969         969           969  0000969.bin  2.076096e+05
# 281         281           281  0000281.bin  9.157809e+04
# 43           43            43  0000043.bin  6.032569e+04
# 676         676           676  0000676.bin  5.330562e+04

# %% [markdown]
# Seems like it starts fairly coplanar, then all the orbital planes separate (by quite a bit), and then seems to be coplanar (one the same plane as IC) three snap shots later

# %%
print os.listdir("../../Corrupted/.")
sys_name = 1364
orbital_times(sys_name=sysm_name)
orbital_evolution(sys_name=sys_name, snapshot="080")
# Out:
# ['Sys_4641_1e8', 'Sys_8582_1e8', 'Sys_13662_1e8', 'Sys_24013_1e8', 'Sys_2059_1e8', 'Sys_1424_1e8', 'Sys_22032_1e8', 'Sys_1886_1e8', 'Sys_2105_1e8', 'Sys_1364_1e8', 'Sys_1508_1e8']
#      Unnamed: 0  Unnamed: 0.1    runstring              t
# 80           80            80  0000080.bin  841993.746348
# 691         691           691  0000691.bin  148903.562359
# 769         769           769  0000769.bin  119116.607637
# 926         926           926  0000926.bin  112855.092073
# 929         929           929  0000929.bin   94792.111299

# %% [markdown]
# Too short for more than one snap shot, cant be ignored

# %%
print os.listdir("../../Corrupted/.")
sys_name = 1508
orbital_times(sys_name=sys_name)
orbital_evolution(sys_name=sys_name, snapshot="824")
# Out:
# ['Sys_4641_1e8', 'Sys_8582_1e8', 'Sys_13662_1e8', 'Sys_24013_1e8', 'Sys_2059_1e8', 'Sys_1424_1e8', 'Sys_22032_1e8', 'Sys_1886_1e8', 'Sys_2105_1e8', 'Sys_1364_1e8', 'Sys_1508_1e8']
#      Unnamed: 0  Unnamed: 0.1    runstring             t
# 824         824           824  0000824.bin  16757.653848
# 439         439           439  0000439.bin  15802.428226
# 147         147           147  0000147.bin  15771.563094
# 523         523           523  0000523.bin  15765.916611
# 450         450           450  0000450.bin  15765.500919
