# %%
# Reading in the data:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('../csvs/initial_orbital_elements.csv', index_col=0)

# %%
df.tail()
# Out:
#          runstring  Stable  instability_time      Rel_Eerr   RHill12  \
# 24995  0024995.bin       0      1.843085e+04  7.079920e-07  0.011837
# 24996  0024996.bin       0      1.868255e+03  2.193370e-07  0.012382
# 24997  0024997.bin       0      6.939622e+04  6.371098e-08  0.022398
# 24998  0024998.bin       0      3.230627e+04  1.499873e-05  0.006648
# 24999  0024999.bin       1      1.000000e+09  2.532040e-08  0.025229
#
#         RHill23     beta12     beta23            m1   a1    ...       Omega2  \
# 24995  0.014329  14.522773  15.079252  6.384047e-07  1.0    ...     0.917172
# 24996  0.025246   9.552527   4.048412  4.383173e-06  1.0    ...    -2.823131
# 24997  0.025432  25.850615   4.666121  3.176214e-05  1.0    ...     1.928687
# 24998  0.016482   8.336998  14.038862  4.817579e-07  1.0    ...    -2.237950
# 24999  0.031384  12.553012  16.970720  4.806837e-05  1.0    ...     1.983032
#
#              f2        m3        a3        P3        e3   pomega3      inc3  \
# ...

# %%
plt.style.use('paper')
fig, ax = plt.subplots(figsize=(15,10))
cm = plt.cm.get_cmap('RdYlBu')
dfplot = df #df.loc[df["Norbits"] > 0.]
sc = ax.scatter(dfplot['beta12'], dfplot['beta23'], c=np.log10(dfplot['instability_time']), edgecolor='', vmin=8.9,s=10,cmap=cm)
ax.set_xlabel(r'$\Delta_1$', fontsize=24)
ax.set_ylabel(r'$\Delta_2$', fontsize=24)
plt.colorbar(sc)

# %%
plt.hist(np.log10(df['instability_time']), 30)
# Out:
# (array([  3.00000000e+00,   1.00000000e+00,   8.00000000e+00,
#           1.60000000e+01,   3.40000000e+01,   9.50000000e+01,
#           2.04000000e+02,   3.89000000e+02,   5.10000000e+02,
#           5.69000000e+02,   5.56000000e+02,   4.86000000e+02,
#           4.69000000e+02,   4.26000000e+02,   4.59000000e+02,
#           4.50000000e+02,   4.79000000e+02,   4.79000000e+02,
#           4.32000000e+02,   4.18000000e+02,   3.92000000e+02,
#           3.40000000e+02,   2.98000000e+02,   2.91000000e+02,
#           2.39000000e+02,   2.41000000e+02,   2.14000000e+02,
#           1.98000000e+02,   1.96000000e+02,   6.10700000e+03]),
#  array([-1.46042191, -1.11174118, -0.76306045, -0.41437972, -0.06569899,
#          0.28298174,  0.63166247,  0.9803432 ,  1.32902394,  1.67770467,
#          2.0263854 ,  2.37506613,  2.72374686,  3.07242759,  3.42110832,
#          3.76978905,  4.11846978,  4.46715051,  4.81583124,  5.16451197,
# ...

# %%
fig, ax = plt.subplots(figsize=(15,10))
cm = plt.cm.get_cmap('RdYlBu')
dfplot = df #df.loc[df["Norbits"] > 0.]
sc = ax.scatter(dfplot['P2']/dfplot['P1'], dfplot['P3']/dfplot['P2'], c=np.log10(dfplot['instability_time']), edgecolor='', vmin=8.9,s=10,cmap=cm)
ax.set_xlabel('P2/P1', fontsize=24)
ax.set_ylabel('P3/P2', fontsize=24)
plt.colorbar(sc)

# %%
df["emax"] = df[["e1", "e2", "e3"]].max(axis=1)

# %%
plt.hist(np.log10(df["emax"]), bins=20)
# Out:
# (array([    5.,     9.,    21.,    48.,    85.,   167.,   232.,   417.,
#           561.,   808.,  1273.,  1533.,  2004.,  2139.,  1886.,  1623.,
#          1209.,   698.,   233.,    48.]),
#  array([-4.14283276, -3.93919592, -3.73555907, -3.53192222, -3.32828538,
#         -3.12464853, -2.92101168, -2.71737484, -2.51373799, -2.31010114,
#         -2.1064643 , -1.90282745, -1.6991906 , -1.49555376, -1.29191691,
#         -1.08828006, -0.88464322, -0.68100637, -0.47736952, -0.27373268,
#         -0.07009583]),
#  <a list of 20 Patch objects>)
