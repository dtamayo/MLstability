# %%
import numpy as np

from bokeh.layouts import row, widgetbox
from bokeh.models import CustomJS, Slider
from bokeh.plotting import figure, output_file, show, ColumnDataSource
from bokeh.io import push_notebook, output_notebook
output_notebook()
x = np.linspace(0, 10, 500)
y = np.sin(x)

source = ColumnDataSource(data=dict(x=x, y=y))

plot = figure(y_range=(-10, 10), plot_width=400, plot_height=400)

plot.line('x', 'y', source=source, line_width=3, line_alpha=0.6)

callback = CustomJS(args=dict(source=source), code="""
    var data = source.data;
    var A = amp.value;
    var k = freq.value;
    var phi = phase.value;
    var B = offset.value;
    x = data['x']
    y = data['y']
    for (i = 0; i < x.length; i++) {
        y[i] = B + A*Math.sin(k*x[i]+phi);
    }
    source.trigger('change');
""")

amp_slider = Slider(start=0.1, end=10, value=1, step=.1,
                    title="Amplitude", callback=callback)
callback.args["amp"] = amp_slider

freq_slider = Slider(start=0.1, end=10, value=1, step=.1,
                     title="Frequency", callback=callback)
callback.args["freq"] = freq_slider

phase_slider = Slider(start=0, end=6.4, value=0, step=.1,
                      title="Phase", callback=callback)
callback.args["phase"] = phase_slider

offset_slider = Slider(start=-5, end=5, value=0, step=.1,
                       title="Offset", callback=callback)
callback.args["offset"] = offset_slider

layout = row(
    plot,
    widgetbox(amp_slider, freq_slider, phase_slider, offset_slider),
)

#output_file("slider.html", title="slider.py example")

show(layout, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b5cda75f-da21-49d0-84e6-661a291a5622">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="08422af0-89cf-429e-94fa-3d82c5fa6193"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("08422af0-89cf-429e-94fa-3d82c5fa6193");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("99129c35-7845-4556-a868-a2676c663b97", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("08422af0-89cf-429e-94fa-3d82c5fa6193");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '08422af0-89cf-429e-94fa-3d82c5fa6193' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9d271404-a393-4751-84c6-ae7529bd29b2":{"roots":{"references":[{"attributes":{"plot":{"id":"a89040eb-0f32-4593-bbd8-4c2f02661bc2","subtype":"Figure","type":"Plot"}},"id":"3e9d6b87-e000-4b40-9227-b6d9656489e9","type":"SaveTool"},{"attributes":{"formatter":{"id":"61b79ad8-df13-42dd-97ac-bf0dd5213f0b","type":"BasicTickFormatter"},"plot":{"id":"a89040eb-0f32-4593-bbd8-4c2f02661bc2","subtype":"Figure","type":"Plot"},"ticker":{"id":"580e6f5b-d922-4f87-85ee-bb7044cd0d08","type":"BasicTicker"}},"id":"1ca7c1d8-fda4-4424-b501-8b83676ccebf","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"ee468610-b2fd-4ac8-a627-314f2c1da915","type":"BoxAnnotation"},{"attributes":{"callback":null,"end":10,"start":-10},"id":"b3bd062a-7ff2-4725-9821-b245c38e2379","type":"Range1d"},{"attributes":{"callback":{"id":"18a3d544-0c98-416b-9936-87df6ca546d9","type":"CustomJS"},"end":10,"start":0.1,"title":"Frequency","value":1},"id":"d52b9840-72fe-4f14-8de2-14f9ec004401","type":"Slider"},{"attributes":{"data_source":{"id":"d2d69a97-0b4c-405a-bccd-d853e9decb48","type":"ColumnDataSource"},"glyph":{"id":"df147f2c-f999-4160-a110-c9a9985b3c06","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"5736dc3c-fbf1-448e-83a5-3c39afc304b4","type":"Line"},"selection_glyph":null},"id":"960e6c3a-56d9-4267-a8fc-6d18e81bdfcb","type":"GlyphRenderer"},{"attributes":{"children":[{"id":"3f4cfc7d-1047-4e5b-9f50-31291ed71990","type":"Slider"},{"id":"d52b9840-72fe-4f14-8de2-14f9ec004401","type":"Slider"},{"id":"97c4f74a-6a70-4593-86fa-8c98156a397e","type":"Slider"},{"id":"26a01c80-3519-4717-87aa-7d09f1dc1723","type":"Slider"}]},"id":"07d218be-f72d-41de-98e5-5f9b09c69a35","type":"WidgetBox"},{"attributes":{"plot":{"id":"a89040eb-0f32-4593-bbd8-4c2f02661bc2","subtype":"Figure","type":"Plot"}},"id":"a548cb38-bdb2-4e62-a6ed-5c59c90ff139","type":"PanTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a548cb38-bdb2-4e62-a6ed-5c59c90ff139","type":"PanTool"},{"id":"0642dd08-ccb6-4b7b-9968-48619b5d2abb","type":"WheelZoomTool"},{"id":"fefc9270-b1d3-43d6-b6d7-37351d8eaf6f","type":"BoxZoomTool"},{"id":"3e9d6b87-e000-4b40-9227-b6d9656489e9","type":"SaveTool"},{"id":"ad301672-4757-472b-a717-467f6ce572a6","type":"ResetTool"},{"id":"5d362962-ff14-47ec-996d-24363cf9d575","type":"HelpTool"}]},"id":"0b2425db-a1c3-4591-bd3f-1dda05acb9f8","type":"Toolbar"},{"attributes":{"callback":null},"id":"4d23c44a-fc53-4141-b482-d44fa75a4066","type":"DataRange1d"},{"attributes":{},"id":"6980a5b5-751e-418c-ab46-5bf2ce531bca","type":"BasicTickFormatter"},{"attributes":{},"id":"11ab47cf-8729-4900-ad6d-03e29c3444e1","type":"ToolEvents"},{"attributes":{"plot":{"id":"a89040eb-0f32-4593-bbd8-4c2f02661bc2","subtype":"Figure","type":"Plot"}},"id":"ad301672-4757-472b-a717-467f6ce572a6","type":"ResetTool"},{"attributes":{"callback":{"id":"18a3d544-0c98-416b-9936-87df6ca546d9","type":"CustomJS"},"end":5,"start":-5,"title":"Offset","value":0},"id":"26a01c80-3519-4717-87aa-7d09f1dc1723","type":"Slider"},{"attributes":{"dimension":1,"plot":{"id":"a89040eb-0f32-4593-bbd8-4c2f02661bc2","subtype":"Figure","type":"Plot"},"ticker":{"id":"4d9002b8-9dd4-47fb-8106-38eee5b33b73","type":"BasicTicker"}},"id":"f791a6a1-56ff-4cb0-9398-f0c5a9b28df2","type":"Grid"},{"attributes":{"plot":{"id":"a89040eb-0f32-4593-bbd8-4c2f02661bc2","subtype":"Figure","type":"Plot"}},"id":"5d362962-ff14-47ec-996d-24363cf9d575","type":"HelpTool"},{"attributes":{"plot":{"id":"a89040eb-0f32-4593-bbd8-4c2f02661bc2","subtype":"Figure","type":"Plot"},"ticker":{"id":"580e6f5b-d922-4f87-85ee-bb7044cd0d08","type":"BasicTicker"}},"id":"e4987660-6c0c-4d4c-8530-32ee1bbc8911","type":" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[2]</strong>&gt;</code></p>
